# %% [markdown]
# # Import necessary packages

# %%
# Visualization
import matplotlib.pyplot as plt
from Sort import sort_for_plotting

# Data Manipulation
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats.power as smp
from scipy.stats import pearsonr, jarque_bera, spearmanr, f_oneway, ttest_ind
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white

# Fitting a model
from Artificial_Neural_Network import ANN
from Decision_Tree_Regression import Decision_Tree_Regression
from Random_Forest_Regression import Random_Forest_Regression
from Regression import Regression
from Spline_Regression import Spline_Regression
from satisfaction_score_data_generator import generate_dataset_with_sensor_readings_and_satisfaction_scores

from tqdm import tnrange, tqdm_notebook

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data Analysis
#
# ### Data Generation
#
# In order to generate the Synthetic Data for the analasys
#
# 1. Indicate the number od samples to generate
# 2. Choose type of a wavelet used for smoothing generated fucntion (i.e. db2, db4, db6, db8...etc.)
# 3. Indicate a value of standard deviation of the gausian noise added to the generated data

# %%
# Generate dataset with the scores and reading using satisfaction_score_data_generator.py
sample_size = 1000
noise_standard_deviation = 0.08
wavelet = 'db8'

satisfaction_vs_sensors, satisfaction_vs_sensors_null = generate_dataset_with_sensor_readings_and_satisfaction_scores(sample_size,
                                                                                        noise_standard_deviation,
                                                                                        wavelet)

# %% [markdown]
# ## Display summary statistics

# %%
satisfaction_vs_sensors.describe()
# Out:
#        sensor_temperature  sensor_humidity  sensor_heat_index   sensor_air  \
# count         1000.000000      1000.000000        1000.000000  1000.000000
# mean            23.558996        51.780609          23.773232  1106.194824
# std              4.849717        19.259392           6.013908   505.075836
# min             15.000008        20.078981          13.801657   250.876404
# 25%             19.220487        34.393581          18.437819   675.476746
# 50%             23.546071        51.981455          23.224277  1073.545593
# 75%             27.638878        68.283638          28.610249  1528.971680
# max             31.999105        84.995018          39.401558  1998.978027
#
#        sensor_light  sensor_noise  comfort_score_temperature  \
# count   1000.000000   1000.000000                1000.000000
# mean     793.406738     52.996292                   0.422378
# std      406.564514     12.766987                   0.255892
# min      102.854103     30.131020                   0.000804
# 25%      436.709114     42.588482                   0.213488
# 50%      788.018860     53.270096                   0.373825
# 75%     1147.042969     63.814470                   0.595822
# max     1499.863525     74.982376                   0.999455
#
#        comfort_score_humidity  comfort_score_heat_index  comfort_score_air  \
# count             1000.000000               1000.000000        1000.000000
# mean                 0.753347                  0.382153           0.533231
# std                  0.209628                  0.260491           0.323522
# min                  0.092879                  0.004213           0.000104
# 25%                  0.601215                  0.174406           0.227718
# 50%                  0.831075                  0.305508           0.508496
# 75%                  0.916704                  0.552429           0.869495
# max                  0.999602                  0.996308           0.999734
#
#        comfort_score_light  comfort_score_noise
# count          1000.000000          1000.000000
# mean              0.622820             0.674377
# std               0.281383             0.283250
# min               0.007830             0.009183
# 25%               0.396477             0.440439
# 50%               0.711660             0.793422
# 75%               0.852856             0.910373
# max               0.999568             0.998881

# %% [markdown]
# ### Plot the correlation matrix

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(satisfaction_vs_sensors.corr(), cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# ### Data distribution plots
#
# Generated data distribution is visualised by using a boxplot and ploting a univariate distribution of observations.

# %%
no_of_columns = np.shape(satisfaction_vs_sensors)[1]
measurements = satisfaction_vs_sensors.columns.values

plt.figure(figsize=(4.5*no_of_columns,5*no_of_columns))
for i in range(0,len(measurements)):
    plt.subplot(no_of_columns + 1, no_of_columns, i + 1)
    sns.distplot(satisfaction_vs_sensors[measurements[i]],kde=True)

# %%
plt.figure(figsize=(no_of_columns,5*no_of_columns))
for i in range(0,len(measurements)):
    plt.subplot(no_of_columns + 1, no_of_columns, i + 1)
    sns.boxplot(satisfaction_vs_sensors[measurements[i]],color='lightblue',orient='v')
    plt.tight_layout()

# %% [markdown]
# ### Divide the dataset into predictors and outcome
#
# In orther to perform predicitons and further analysis, a measurement of interest has to be extracted from the generated dataset and divided into predictors (independent variable X) and outcome (dependent variable y).
#
# The name of the measurement/score of interest can be specified by assigning a string value to the variable ***measurement_name*** from:
#     * temperature
#     * humidity
#     * heat_index
#     * air
#     * light
#     * noise

# %%
# Specify the name of the measurement/score of interest
# Choose from: temperature, humidity, heat_index, air, light, noise

measurement_name = 'air'
sensor_name = f'sensor_{measurement_name}'
score_name = f'comfort_score_{measurement_name}'

# Divide the dataset into predictors and outcome

X = satisfaction_vs_sensors[[sensor_name]]
y = satisfaction_vs_sensors[[score_name]]

# %% [markdown]
# ### Visualise the variables
#
# In order to visualise the data correctly by plotting the result of the prediction model or to plot the original data a funtion **Function sort_for_plotting** is used to sort the values before plotting

# %%
def sort_for_plotting(X, y):
    data_set = np.column_stack((X, y))
    test_set_sorted = data_set[data_set[:, 0].argsort()]
    X_sorted = test_set_sorted[:, 0]
    y_sorted = test_set_sorted[:, 1]

    return X_sorted, y_sorted

# %%
# Plot the original data
X_sorted, y_sorted = sort_for_plotting(X, y)

plt.figure(figsize=(12, 10))
plt.plot(X_sorted, y_sorted)
plt.xlabel(f"{sensor_name}")
plt.ylabel(f"{score_name}")
plt.title(f'Satisfaction vs indoor conditions (Generated data)')
plt.show()

# %% [markdown]
# ### Jarque-Bera Test
#
# Data is checked for normal distribution. If a variable doesn't have a normal distrubution, a logarithmic transformation is applied and tested.
#
# H0: Data is normally distributed
#
# H1: Skewness and kurtosis doesn't match a normal distribution
#
# H0 is rejected when p-value < 0.05

# %%
statistics_jb_X, p_value_jb_X = jarque_bera(X)
statistics_jb_y, p_value_jb_y = jarque_bera(y)

# Plot variable to examine its distribution
sns.distplot(y) 

# If the variable doesn't have a normal distribution check if it has log-normal distribution
X_log = np.log(X)
y_log = np.log(X_log)

statistics_jb_X_log, p_value_jb_X_log = jarque_bera(X_log)
statistics_jb_y_log, p_value_jb_y_log = jarque_bera(y_log) 

# Plot a transformed variable to examine its distribution
sns.distplot(y_log) 

print(f'Jarque-Bera Test for X: statistics = {statistics_jb_X}; p-value = {p_value_jb_X}')
print(f'Jarque-Bera Test for y: statistics = {statistics_jb_y}; p-value = {p_value_jb_y}')

print(f'Jarque-Bera Test for X_log: statistics = {statistics_jb_X_log}; p-value = {p_value_jb_X_log}')
print(f'Jarque-Bera Test for y_log: statistics = {statistics_jb_y_log}; p-value = {p_value_jb_y_log}')
# Out:
# Jarque-Bera Test for X: statistics = 56.529582027343544; p-value = 5.305755834683623e-13
# Jarque-Bera Test for y: statistics = 90.71255169970819; p-value = 0.0
# Jarque-Bera Test for X_log: statistics = 103.74030287849206; p-value = 0.0
# Jarque-Bera Test for y_log: statistics = 133.20081747028695; p-value = 0.0

# %% [markdown]
# ### Spearman and Pearson test for correlation
#
# Pearson correlation coefficient assumes a normal distribution. When a variable is not normally distributed use Spearman's rank correlation.
#
# H0: There is no correlation
#
# H1: Correlation coefficient is statistically significant

# %%
rho, p_value_spearman = spearmanr(X, y)
r, p_value_pearson = pearsonr(X.iloc[:, 0], y.iloc[:, 0])

print(f'Correlation Spearman = {rho}, p-value = {p_value_spearman}')
print(f'Correlation Pearson = {r}, p-value = {p_value_pearson}')
# Out:
# Correlation Spearman = -0.9379087970669178, p-value = 0.0
# Correlation Pearson = -0.9433973144604374, p-value = 0.0

# %% [markdown]
# ### Statistical power for regression
#
# Power is genarlly estimating a probablity that the regression finding is statistically significant.
# For instance, having 90% power means that 90% of samples collected from the same population will demonstrate a significant relationship (H0 is rejected).
#
# Power can be determined by calculating L value, which is a non-centrality parameter and reading the value from the table below for a given number of predictors $k$.
#
# ![image.png](attachment:image.png)
#
# Cohen, J. (2013). Statistical power analysis for the behavioral sciences. Routledge.

# %%
# Set parameters to perform the test
R2_regression = 0.6
number_of_predictors_degrees = 3
sample_size = 10

# Effect size can be calculated using the R2 statistic 
cohen_effect_size = R2_regression / (1 - R2_regression)
# squared_correlation_coefficient_effect_size = r**2

L_value_non_centrality_parameter = cohen_effect_size * (sample_size - number_of_predictors_degrees - 1)

# Read the power from the table based on non centrality parameter
L_value_non_centrality_parameter
# Out:
# 8.999999999999998

# %%
# Set parameters to perform the sample size estimation using L-value
R2_regression = 0.4
number_of_predictors_degrees = 3

# Read from the tables e.g. for 80% power and 3 predictors the value is:
L_value = 10.9

# Effect size can be calculated using the R2 statistic 
cohen_effect_size = R2_regression / (1 - R2_regression)

estimated_sample_size = (L_value / cohen_effect_size) + number_of_predictors_degrees + 1
estimated_sample_size
# Out:
# 20.349999999999998

# %% [markdown]
# ### Size of a sample needed
# One-sample t-test is another method to determine the sample size given the needed test power, significance level and the effect size (or to determine the power).

# %%
# Set parameters to perform the test, put "None" by the parameter that is needed to be calculated
R2_regression = 0.4
effect_size = R2_regression / (1 - R2_regression) #ignore
number_of_observations = None
significance = 0.05
test_power = 0.9

power_test = smp.TTestPower().solve_power(effect_size=effect_size, nobs=number_of_observations, alpha=significance,
                                    power = test_power, alternative='larger')

print(f'Sample Size: {power_test}') 
# all the results give a very small sample 
# Maybe square of the Pearson correlation coefficient would be better as an effect size - size of a sample is huge
#how extreme the correlation has to be to reject the null model - how many false positive we allow
# effect size - shifting from 0 how easy is to tell apart null form alternative
#null model slope is 0 - alternative slope is e.g. 1
# use bootstrap for power analysis
# Out:
# Sample Size: 20.699143325387332

# %%
effect_size
# Out:
# 0.6666666666666667

# %% [markdown]
# ### Power plots
#
# Plots presented below allow see how the power changes with number of observations and effect size

# %%
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(2,1,1)
fig = smp.TTestPower().plot_power(dep_var='nobs',
                                  nobs= np.arange(2, 120),
                                  effect_size=np.array([0.4, 0.6, 0.8, 1, 1.5, 2]),
                                  alternative='larger',
                                  ax=ax, title='T-Test Power')
ax = fig.add_subplot(2,1,2)
fig = smp.TTestPower().plot_power(dep_var='es',
                                  nobs=np.array([10, 20, 40, 60, 80, 100]),
                                  effect_size=np.linspace(0.1, 2),
                                  alternative='larger',
                                  ax=ax, title='')

# %% [markdown]
# ### Ordinary Least Squares (OLS) model
#
# Summary statistics for the OLS displayes the R-squared that shows how well the data fits the model.
#
# F-statistic that measures the significance of the fit and T-statistics measures the significance of the estimated coefficients.
#
# F-statistic:
#
#     H0: All of the regression coefficients are equal to zero
#
#     H1: Model has good predictive capability
#
# T-statistics:
#
#     H0: Variable is not signoificant to the model
#
#     H1: Significant relationship between the response and explanatory variables
#
#
# In terms of the model residual distribution, Jarque-Bera Test for the normality

# %%
degree = 1

# Perform polynomial transformation
polynomial_features = PolynomialFeatures(degree=degree)
X_polynomial = polynomial_features.fit_transform(X)

# Fit the model
model = sm.OLS(y, X_polynomial).fit()
y_predicted = model.predict(X_polynomial)

slope, intercept = np.polyfit(np.log(X.iloc[:, 0]), np.log(y.iloc[:, 0]), 1)

# Plot the prediction
plt.scatter(X,y)
X_sorted, y_sorted_p = sort_for_plotting(X, y_predicted)
plt.plot(X_sorted, y_sorted_p)
plt.show()

# Show summary statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      comfort_score_air   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     8075.
# Date:                Mon, 04 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:04:13   Log-Likelihood:                 832.54
# No. Observations:                1000   AIC:                            -1661.
# Df Residuals:                     998   BIC:                            -1651.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1962      0.008    144.672      0.000       1.180       1.212
# x1            -0.0006   6.71e-06    -89.859      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                       15.176   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.269
# Skew:                          -0.039   Prob(JB):                      0.00971
# Kurtosis:                       2.535   Cond. No.                     3.06e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Test for Heteroskedasticity
#
# H0: Homoskedasticity
#
# H1: Heteroskedasticity

# %%
bp_test = het_breuschpagan(model.resid, X_polynomial)
white_test = het_white(model.resid,  model.model.exog)

labels = ['Lagrange Multiplier Statistic', 'Lagrange Multiplier-Test p-value', 'F-Statistic', 'F-Test p-value']

print(dict(zip(labels, bp_test)))
print(dict(zip(labels, white_test)))
# Out:
# {'Lagrange Multiplier Statistic': 8.134507682460379, 'Lagrange Multiplier-Test p-value': 0.004343063821129393, 'F-Statistic': 8.184818133078558, 'F-Test p-value': 0.004312395075947836}
# {'Lagrange Multiplier Statistic': 8.606178345116898, 'Lagrange Multiplier-Test p-value': 0.013526708067719273, 'F-Statistic': 4.327422474632102, 'F-Test p-value': 0.013450385126443478}

# %% [markdown]
# ## ANOVA Test
#
# The ANOVA test has important assumptions that must be satisfied in order for the associated p-value to be valid.
#
# 1. The samples are independent.
# 2. Each sample is from a normally distributed population.
# 3. The population standard deviations of the groups are all equal. This property is known as homoscedasticity.
#
# H0: $\mu_1 = \mu_2$
#
# H1: $\mu_1 \neq \mu_2$

# %%
# F_statistic, p_value_anova = f_oneway(X, y)

# print(f'ANOVA F-statistic = {F_statistic}, p-value = {p_value_anova}')

# Compute ANOVA
# anova_results = pg.anova(dv=score_name, between=sensor_name, data=satisfaction_vs_sensors_sorted)

# pg.print_table(anova_results)

# %% [markdown]
# ### T-test for the means of two independent samples of scores.
#
# H0: $\mu_1 = \mu_2$
#
# H1: $\mu_1 \neq \mu_2$

# %%
# t_statistics, p_value_t = ttest_ind(X, y)

# %% [markdown]
# # Model Testing
#
# All the methods are tested over various parameters in order to find the best set.

# %% [markdown]
# ## Random Forest
#
# This method takes as parameters maximum depth of the tree: **max_depth** and number of trees in the forest: **n_estimators**

# %%
max_depth = [4, 5, 6]
n_estimators = [10, 50, 100, 200]
Results_Random_Forest_list = []

plt.figure(figsize=(12, 10))

for depth in tqdm_notebook(max_depth):
    for estimator in n_estimators:
        R2_random_forest, MSE_random_forest = Random_Forest_Regression(X, y, depth, estimator, 'plot', sensor_name,
                                                                       score_name)
        Results_Random_Forest_list.append([depth, estimator, R2_random_forest, MSE_random_forest])
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))

# %% [markdown]
# #### Display the results for Random Forest
# Results of the testing are displayed in the table below, sorted accoding to R2.

# %%
Results_Random_Forest = pd.DataFrame(Results_Random_Forest_list, columns=['max_depth', 'n_estimators',
                                                                     'R2_random_forest', 'MSE_random_forest'])
Results_Random_Forest.sort_values(['R2_random_forest'], ascending = False)
# Out:
#     max_depth  n_estimators  R2_random_forest  MSE_random_forest
# 3           4           200          0.946526           0.073540
# 2           4           100          0.946117           0.073820
# 1           4            50          0.945919           0.073955
# 7           5           200          0.945752           0.074069
# 6           5           100          0.945218           0.074434
# 5           5            50          0.945073           0.074532
# 0           4            10          0.944816           0.074706
# 11          6           200          0.944310           0.075047
# 4           5            10          0.944105           0.075186
# 9           6            50          0.944102           0.075188
# 10          6           100          0.943942           0.075295
# 8           6            10          0.943521           0.075577

# %% [markdown]
# ## Boosted Decision Tree Regression
#
# This method takes as parameters maximum depth of the tree: **max_depth** and maximum number of estimators at which boosting is terminated: **n_estimators**

# %%
max_depth = [4, 5, 6]
n_estimators = [10, 50, 100, 200]
Results_Decision_Tree_list = []

plt.figure(figsize=(12, 10))
for depth in tqdm_notebook(max_depth):
    for estimator in n_estimators:
        R2_decision_tree, MSE_decision_tree = Decision_Tree_Regression(X, y, depth, estimator, 'plot', sensor_name,
                                                                       score_name)
        Results_Decision_Tree_list.append([depth, estimator, R2_decision_tree, MSE_decision_tree])
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))

# %% [markdown]
# #### Display the results for Boosted Decision Tree

# %%
Results_Decision_Tree = pd.DataFrame(Results_Decision_Tree_list, columns=['max_depth', 'n_estimators',
                                                                          'R2_decision_tree', 'MSE_decision_tree'])
Results_Decision_Tree.sort_values(['R2_decision_tree'], ascending=False)
# Out:
#     max_depth  n_estimators  R2_decision_tree  MSE_decision_tree
# 3           4           200          0.945744           0.074075
# 0           4            10          0.945077           0.074529
# 4           5            10          0.944929           0.074629
# 5           5            50          0.944507           0.074915
# 2           4           100          0.943088           0.075866
# 8           6            10          0.942193           0.076461
# 6           5           100          0.941829           0.076701
# 1           4            50          0.941571           0.076871
# 10          6           100          0.941437           0.076959
# 7           5           200          0.941133           0.077159
# 9           6            50          0.941046           0.077216
# 11          6           200          0.940828           0.077358

# %% [markdown]
# ## Artificial Neural Networks
#
# This method takes as parameters number of nodes (neurons): **number_of_nodes** and layers: **number_of_layers** in the Neural Network architecture. In order to reduce overfitting dropout and regularization are applied. Variables **dropout_rate** and **regularization_penalty** introduce the necessary modifications. Lastly, the number of training iterations is determined by parameter: **number_of_epochs**.

# %%
# Chose the number of neurons and number of hidden layers and a dropout rate

number_of_nodes = [30, 100]
number_of_layers = [2, 10]
dropout_rate = [0.1, 0.2]
number_of_epochs = [500, 1000]
regularization_penalty = [0.1, 0.001, 0.0001]
Results_ANN_list = []

# Fit ANN model

plt.figure(figsize=(12, 10))

for nodes in tqdm_notebook(number_of_nodes):
    for layers in tqdm_notebook(number_of_layers):
        for dropout in tqdm_notebook(dropout_rate):
            for epochs in tqdm_notebook(number_of_epochs):
                for regularization in tqdm_notebook(regularization_penalty):
                    R2_ANN, MSE_ANN, training_history = ANN(X, y, nodes, layers, dropout, epochs, regularization,
                                                            'plot', sensor_name, score_name)
                    Results_ANN_list.append([nodes, layers, dropout, epochs, regularization, R2_ANN, MSE_ANN])
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# Train on 666 samples, validate on 334 samples
# Epoch 1/500
# 666/666 [==============================] - ETA: 2s - loss: 3.7111 - mean_squared_error: 0.29 - 0s 298us/step - loss: 3.3968 - mean_squared_error: 0.2515 - val_loss: 3.0163 - val_mean_squared_error: 0.1601
# Epoch 2/500
# 666/666 [==============================] - ETA: 0s - loss: 3.0206 - mean_squared_error: 0.16 - 0s 45us/step - loss: 2.7471 - mean_squared_error: 0.1247 - val_loss: 2.4459 - val_mean_squared_error: 0.0713
# Epoch 3/500
# 666/666 [==============================] - ETA: 0s - loss: 2.4875 - mean_squared_error: 0.11 - 0s 46us/step - loss: 2.2363 - mean_squared_error: 0.0618 - val_loss: 1.9977 - val_mean_squared_error: 0.0369
# Epoch 4/500
# 666/666 [==============================] - ETA: 0s - loss: 2.0074 - mean_squared_error: 0.04 - 0s 45us/step - loss: 1.8291 - mean_squared_error: 0.0403 - val_loss: 1.6351 - val_mean_squared_error: 0.0276
# Epoch 5/500
# 666/666 [==============================] - ETA: 0s - loss: 1.6391 - mean_squared_error: 0.03 - 0s 48us/step - loss: 1.4956 - mean_squared_error: 0.0311 - val_loss: 1.3382 - val_mean_squared_error: 0.0240
# Epoch 6/500
# 666/666 [==============================] - ETA: 0s - loss: 1.3459 - mean_squared_error: 0.03 - 0s 49us/step - loss: 1.2287 - mean_squared_error: 0.0324 - val_loss: 1.0961 - val_mean_squared_error: 0.0233
# Epoch 7/500
# 666/666 [==============================] - ETA: 0s - loss: 1.0983 - mean_squared_error: 0.02 - 0s 55us/step - loss: 1.0072 - mean_squared_error: 0.0305 - val_loss: 0.8988 - val_mean_squared_error: 0.0230
# Epoch 8/500
# 666/666 [==============================] - ETA: 0s - loss: 0.8965 - mean_squared_error: 0.02 - 0s 48us/step - loss: 0.8264 - mean_squared_error: 0.0294 - val_loss: 0.7388 - val_mean_squared_error: 0.0230
# Epoch 9/500
# 666/666 [==============================] - ETA: 0s - loss: 0.7385 - mean_squared_error: 0.02 - 0s 49us/step - loss: 0.6818 - mean_squared_error: 0.0299 - val_loss: 0.6092 - val_mean_squared_error: 0.0236
# Epoch 10/500
# 666/666 [==============================] - ETA: 0s - loss: 0.6109 - mean_squared_error: 0.02 - 0s 48us/step - loss: 0.5636 - mean_squared_error: 0.0291 - val_loss: 0.5045 - val_mean_squared_error: 0.0232
# Epoch 11/500
# 666/666 [==============================] - ETA: 0s - loss: 0.5055 - mean_squared_error: 0.02 - 0s 46us/step - loss: 0.4698 - mean_squared_error: 0.0308 - val_loss: 0.4204 - val_mean_squared_error: 0.0252
# Epoch 12/500
# 666/666 [==============================] - ETA: 0s - loss: 0.4350 - mean_squared_error: 0.03 - 0s 48us/step - loss: 0.3929 - mean_squared_error: 0.0310 - val_loss: 0.3533 - val_mean_squared_error: 0.0270
# Epoch 13/500
# 666/666 [==============================] - ETA: 0s - loss: 0.3574 - mean_squared_error: 0.03 - 0s 51us/step - loss: 0.3321 - mean_squared_error: 0.0330 - val_loss: 0.3004 - val_mean_squared_error: 0.0290
# Epoch 14/500
# 666/666 [==============================] - ETA: 0s - loss: 0.2986 - mean_squared_error: 0.02 - 0s 49us/step - loss: 0.2843 - mean_squared_error: 0.0341 - val_loss: 0.2586 - val_mean_squared_error: 0.0305
# Epoch 15/500
# 666/666 [==============================] - ETA: 0s - loss: 0.2564 - mean_squared_error: 0.02 - 0s 45us/step - loss: 0.2452 - mean_squared_error: 0.0340 - val_loss: 0.2262 - val_mean_squared_error: 0.0328
# Epoch 16/500
# 666/666 [==============================] - ETA: 0s - loss: 0.2312 - mean_squared_error: 0.03 - 0s 46us/step - loss: 0.2179 - mean_squared_error: 0.0379 - val_loss: 0.2009 - val_mean_squared_error: 0.0345
# Epoch 17/500
# 666/666 [==============================] - ETA: 0s - loss: 0.2093 - mean_squared_error: 0.04 - 0s 48us/step - loss: 0.1958 - mean_squared_error: 0.0401 - val_loss: 0.1814 - val_mean_squared_error: 0.0365
# Epoch 18/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1806 - mean_squared_error: 0.03 - 0s 51us/step - loss: 0.1769 - mean_squared_error: 0.0402 - val_loss: 0.1664 - val_mean_squared_error: 0.0387
# Epoch 19/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1688 - mean_squared_error: 0.04 - 0s 48us/step - loss: 0.1659 - mean_squared_error: 0.0444 - val_loss: 0.1547 - val_mean_squared_error: 0.0400
# Epoch 20/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1509 - mean_squared_error: 0.03 - 0s 49us/step - loss: 0.1540 - mean_squared_error: 0.0450 - val_loss: 0.1459 - val_mean_squared_error: 0.0427
# Epoch 21/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1479 - mean_squared_error: 0.04 - 0s 46us/step - loss: 0.1454 - mean_squared_error: 0.0458 - val_loss: 0.1390 - val_mean_squared_error: 0.0431
# Epoch 22/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1399 - mean_squared_error: 0.04 - 0s 45us/step - loss: 0.1406 - mean_squared_error: 0.0485 - val_loss: 0.1337 - val_mean_squared_error: 0.0447
# Epoch 23/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1397 - mean_squared_error: 0.05 - 0s 48us/step - loss: 0.1347 - mean_squared_error: 0.0483 - val_loss: 0.1296 - val_mean_squared_error: 0.0465
# Epoch 24/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1420 - mean_squared_error: 0.05 - 0s 45us/step - loss: 0.1309 - mean_squared_error: 0.0494 - val_loss: 0.1265 - val_mean_squared_error: 0.0471
# Epoch 25/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1275 - mean_squared_error: 0.04 - 0s 49us/step - loss: 0.1287 - mean_squared_error: 0.0513 - val_loss: 0.1242 - val_mean_squared_error: 0.0489
# Epoch 26/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1358 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1281 - mean_squared_error: 0.0543 - val_loss: 0.1224 - val_mean_squared_error: 0.0498
# Epoch 27/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1348 - mean_squared_error: 0.06 - 0s 48us/step - loss: 0.1256 - mean_squared_error: 0.0543 - val_loss: 0.1211 - val_mean_squared_error: 0.0509
# Epoch 28/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1272 - mean_squared_error: 0.05 - 0s 49us/step - loss: 0.1236 - mean_squared_error: 0.0546 - val_loss: 0.1201 - val_mean_squared_error: 0.0524
# Epoch 29/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1304 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1228 - mean_squared_error: 0.0557 - val_loss: 0.1196 - val_mean_squared_error: 0.0536
# Epoch 30/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1091 - mean_squared_error: 0.04 - 0s 45us/step - loss: 0.1237 - mean_squared_error: 0.0584 - val_loss: 0.1188 - val_mean_squared_error: 0.0538
# Epoch 31/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1207 - mean_squared_error: 0.05 - 0s 49us/step - loss: 0.1223 - mean_squared_error: 0.0581 - val_loss: 0.1184 - val_mean_squared_error: 0.0553
# Epoch 32/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1278 - mean_squared_error: 0.06 - 0s 48us/step - loss: 0.1223 - mean_squared_error: 0.0597 - val_loss: 0.1180 - val_mean_squared_error: 0.0560
# Epoch 33/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1237 - mean_squared_error: 0.06 - 0s 48us/step - loss: 0.1205 - mean_squared_error: 0.0593 - val_loss: 0.1178 - val_mean_squared_error: 0.0573
# Epoch 34/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1242 - mean_squared_error: 0.06 - 0s 48us/step - loss: 0.1209 - mean_squared_error: 0.0605 - val_loss: 0.1177 - val_mean_squared_error: 0.0574
# Epoch 35/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1222 - mean_squared_error: 0.06 - 0s 48us/step - loss: 0.1212 - mean_squared_error: 0.0615 - val_loss: 0.1175 - val_mean_squared_error: 0.0586
# Epoch 36/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1282 - mean_squared_error: 0.06 - 0s 49us/step - loss: 0.1218 - mean_squared_error: 0.0630 - val_loss: 0.1174 - val_mean_squared_error: 0.0588
# Epoch 37/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1382 - mean_squared_error: 0.07 - 0s 49us/step - loss: 0.1201 - mean_squared_error: 0.0624 - val_loss: 0.1174 - val_mean_squared_error: 0.0604
# Epoch 38/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1222 - mean_squared_error: 0.06 - 0s 49us/step - loss: 0.1203 - mean_squared_error: 0.0636 - val_loss: 0.1172 - val_mean_squared_error: 0.0609
# Epoch 39/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1148 - mean_squared_error: 0.05 - 0s 48us/step - loss: 0.1197 - mean_squared_error: 0.0633 - val_loss: 0.1172 - val_mean_squared_error: 0.0614
# Epoch 40/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1399 - mean_squared_error: 0.08 - 0s 45us/step - loss: 0.1194 - mean_squared_error: 0.0640 - val_loss: 0.1171 - val_mean_squared_error: 0.0625
# Epoch 41/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1292 - mean_squared_error: 0.07 - 0s 46us/step - loss: 0.1190 - mean_squared_error: 0.0647 - val_loss: 0.1171 - val_mean_squared_error: 0.0632
# Epoch 42/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1116 - mean_squared_error: 0.05 - 0s 48us/step - loss: 0.1203 - mean_squared_error: 0.0671 - val_loss: 0.1171 - val_mean_squared_error: 0.0643
# Epoch 43/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1300 - mean_squared_error: 0.07 - 0s 46us/step - loss: 0.1198 - mean_squared_error: 0.0662 - val_loss: 0.1170 - val_mean_squared_error: 0.0643
# Epoch 44/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1193 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1190 - mean_squared_error: 0.0678 - val_loss: 0.1170 - val_mean_squared_error: 0.0662
# Epoch 45/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1226 - mean_squared_error: 0.07 - 0s 48us/step - loss: 0.1194 - mean_squared_error: 0.0686 - val_loss: 0.1169 - val_mean_squared_error: 0.0663
# Epoch 46/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1001 - mean_squared_error: 0.04 - 0s 45us/step - loss: 0.1199 - mean_squared_error: 0.0693 - val_loss: 0.1169 - val_mean_squared_error: 0.0667
# Epoch 47/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1150 - mean_squared_error: 0.06 - 0s 48us/step - loss: 0.1196 - mean_squared_error: 0.0706 - val_loss: 0.1169 - val_mean_squared_error: 0.0679
# Epoch 48/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1193 - mean_squared_error: 0.07 - 0s 48us/step - loss: 0.1190 - mean_squared_error: 0.0701 - val_loss: 0.1169 - val_mean_squared_error: 0.0683
# Epoch 49/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1315 - mean_squared_error: 0.08 - 0s 49us/step - loss: 0.1204 - mean_squared_error: 0.0722 - val_loss: 0.1169 - val_mean_squared_error: 0.0691
# Epoch 50/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1268 - mean_squared_error: 0.07 - 0s 49us/step - loss: 0.1206 - mean_squared_error: 0.0730 - val_loss: 0.1168 - val_mean_squared_error: 0.0697
# Epoch 51/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1076 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1195 - mean_squared_error: 0.0732 - val_loss: 0.1168 - val_mean_squared_error: 0.0714
# Epoch 52/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1149 - mean_squared_error: 0.06 - 0s 45us/step - loss: 0.1196 - mean_squared_error: 0.0734 - val_loss: 0.1168 - val_mean_squared_error: 0.0707
# Epoch 53/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1289 - mean_squared_error: 0.08 - 0s 49us/step - loss: 0.1207 - mean_squared_error: 0.0761 - val_loss: 0.1167 - val_mean_squared_error: 0.0725
# Epoch 54/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1130 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1194 - mean_squared_error: 0.0762 - val_loss: 0.1167 - val_mean_squared_error: 0.0737
# Epoch 55/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1068 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1208 - mean_squared_error: 0.0783 - val_loss: 0.1166 - val_mean_squared_error: 0.0752
# Epoch 56/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1235 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1187 - mean_squared_error: 0.0773 - val_loss: 0.1166 - val_mean_squared_error: 0.0753
# Epoch 57/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1097 - mean_squared_error: 0.06 - 0s 45us/step - loss: 0.1190 - mean_squared_error: 0.0784 - val_loss: 0.1165 - val_mean_squared_error: 0.0764
# Epoch 58/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1083 - mean_squared_error: 0.06 - 0s 43us/step - loss: 0.1176 - mean_squared_error: 0.0777 - val_loss: 0.1165 - val_mean_squared_error: 0.0771
# Epoch 59/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1035 - mean_squared_error: 0.06 - 0s 45us/step - loss: 0.1188 - mean_squared_error: 0.0795 - val_loss: 0.1164 - val_mean_squared_error: 0.0780
# Epoch 60/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1088 - mean_squared_error: 0.07 - 0s 43us/step - loss: 0.1179 - mean_squared_error: 0.0805 - val_loss: 0.1163 - val_mean_squared_error: 0.0793
# Epoch 61/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1025 - mean_squared_error: 0.06 - 0s 46us/step - loss: 0.1195 - mean_squared_error: 0.0831 - val_loss: 0.1162 - val_mean_squared_error: 0.0803
# Epoch 62/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1173 - mean_squared_error: 0.08 - 0s 42us/step - loss: 0.1179 - mean_squared_error: 0.0824 - val_loss: 0.1162 - val_mean_squared_error: 0.0819
# Epoch 63/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1138 - mean_squared_error: 0.07 - 0s 42us/step - loss: 0.1180 - mean_squared_error: 0.0847 - val_loss: 0.1161 - val_mean_squared_error: 0.0826
# Epoch 64/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1160 - mean_squared_error: 0.08 - 0s 43us/step - loss: 0.1180 - mean_squared_error: 0.0846 - val_loss: 0.1159 - val_mean_squared_error: 0.0835
# Epoch 65/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1086 - mean_squared_error: 0.07 - 0s 43us/step - loss: 0.1195 - mean_squared_error: 0.0879 - val_loss: 0.1158 - val_mean_squared_error: 0.0857
# Epoch 66/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1107 - mean_squared_error: 0.08 - 0s 43us/step - loss: 0.1178 - mean_squared_error: 0.0885 - val_loss: 0.1156 - val_mean_squared_error: 0.0865
# Epoch 67/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1156 - mean_squared_error: 0.08 - 0s 43us/step - loss: 0.1181 - mean_squared_error: 0.0892 - val_loss: 0.1154 - val_mean_squared_error: 0.0879
# Epoch 68/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1179 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1183 - mean_squared_error: 0.0920 - val_loss: 0.1151 - val_mean_squared_error: 0.0895
# Epoch 69/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1186 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1171 - mean_squared_error: 0.0922 - val_loss: 0.1149 - val_mean_squared_error: 0.0904
# Epoch 70/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1316 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1177 - mean_squared_error: 0.0942 - val_loss: 0.1145 - val_mean_squared_error: 0.0924
# Epoch 71/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1067 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1163 - mean_squared_error: 0.0943 - val_loss: 0.1142 - val_mean_squared_error: 0.0933
# Epoch 72/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0919 - mean_squared_error: 0.07 - 0s 46us/step - loss: 0.1152 - mean_squared_error: 0.0952 - val_loss: 0.1138 - val_mean_squared_error: 0.0950
# Epoch 73/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1012 - mean_squared_error: 0.08 - 0s 45us/step - loss: 0.1161 - mean_squared_error: 0.0977 - val_loss: 0.1134 - val_mean_squared_error: 0.0959
# Epoch 74/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1420 - mean_squared_error: 0.12 - 0s 46us/step - loss: 0.1160 - mean_squared_error: 0.0993 - val_loss: 0.1130 - val_mean_squared_error: 0.0970
# Epoch 75/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1023 - mean_squared_error: 0.08 - 0s 45us/step - loss: 0.1151 - mean_squared_error: 0.1001 - val_loss: 0.1125 - val_mean_squared_error: 0.0982
# Epoch 76/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1264 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1144 - mean_squared_error: 0.1003 - val_loss: 0.1122 - val_mean_squared_error: 0.0989
# Epoch 77/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0945 - mean_squared_error: 0.08 - 0s 48us/step - loss: 0.1151 - mean_squared_error: 0.1035 - val_loss: 0.1116 - val_mean_squared_error: 0.1007
# Epoch 78/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1299 - mean_squared_error: 0.11 - 0s 49us/step - loss: 0.1135 - mean_squared_error: 0.1028 - val_loss: 0.1111 - val_mean_squared_error: 0.1008
# Epoch 79/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1101 - mean_squared_error: 0.09 - 0s 43us/step - loss: 0.1133 - mean_squared_error: 0.1036 - val_loss: 0.1105 - val_mean_squared_error: 0.1017
# Epoch 80/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1131 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1126 - mean_squared_error: 0.1040 - val_loss: 0.1100 - val_mean_squared_error: 0.1021
# Epoch 81/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1244 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1119 - mean_squared_error: 0.1046 - val_loss: 0.1096 - val_mean_squared_error: 0.1025
# Epoch 82/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1375 - mean_squared_error: 0.13 - 0s 45us/step - loss: 0.1120 - mean_squared_error: 0.1051 - val_loss: 0.1091 - val_mean_squared_error: 0.1029
# Epoch 83/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1095 - mean_squared_error: 0.10 - 0s 49us/step - loss: 0.1114 - mean_squared_error: 0.1058 - val_loss: 0.1087 - val_mean_squared_error: 0.1034
# Epoch 84/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1222 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1108 - mean_squared_error: 0.1054 - val_loss: 0.1084 - val_mean_squared_error: 0.1033
# Epoch 85/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1071 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1104 - mean_squared_error: 0.1058 - val_loss: 0.1079 - val_mean_squared_error: 0.1036
# Epoch 86/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1051 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1093 - mean_squared_error: 0.1052 - val_loss: 0.1077 - val_mean_squared_error: 0.1040
# Epoch 87/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1143 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1100 - mean_squared_error: 0.1062 - val_loss: 0.1074 - val_mean_squared_error: 0.1037
# Epoch 88/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0893 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1090 - mean_squared_error: 0.1055 - val_loss: 0.1071 - val_mean_squared_error: 0.1038
# Epoch 89/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1167 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1090 - mean_squared_error: 0.1059 - val_loss: 0.1069 - val_mean_squared_error: 0.1038
# Epoch 90/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1148 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1083 - mean_squared_error: 0.1054 - val_loss: 0.1067 - val_mean_squared_error: 0.1039
# Epoch 91/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0972 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1090 - mean_squared_error: 0.1061 - val_loss: 0.1065 - val_mean_squared_error: 0.1038
# Epoch 92/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1052 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1078 - mean_squared_error: 0.1051 - val_loss: 0.1063 - val_mean_squared_error: 0.1038
# Epoch 93/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1072 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1080 - mean_squared_error: 0.1056 - val_loss: 0.1061 - val_mean_squared_error: 0.1039
# Epoch 94/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1231 - mean_squared_error: 0.12 - 0s 48us/step - loss: 0.1080 - mean_squared_error: 0.1059 - val_loss: 0.1060 - val_mean_squared_error: 0.1040
# Epoch 95/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0989 - mean_squared_error: 0.09 - 0s 51us/step - loss: 0.1079 - mean_squared_error: 0.1059 - val_loss: 0.1059 - val_mean_squared_error: 0.1038
# Epoch 96/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1128 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1072 - mean_squared_error: 0.1051 - val_loss: 0.1058 - val_mean_squared_error: 0.1038
# Epoch 97/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1402 - mean_squared_error: 0.13 - 0s 48us/step - loss: 0.1070 - mean_squared_error: 0.1052 - val_loss: 0.1056 - val_mean_squared_error: 0.1039
# Epoch 98/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1138 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1072 - mean_squared_error: 0.1055 - val_loss: 0.1055 - val_mean_squared_error: 0.1039
# Epoch 99/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1095 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1063 - mean_squared_error: 0.1049 - val_loss: 0.1054 - val_mean_squared_error: 0.1039
# Epoch 100/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1041 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1076 - mean_squared_error: 0.1059 - val_loss: 0.1055 - val_mean_squared_error: 0.1039
# Epoch 101/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1092 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1067 - mean_squared_error: 0.1053 - val_loss: 0.1052 - val_mean_squared_error: 0.1039
# Epoch 102/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1107 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1073 - mean_squared_error: 0.1059 - val_loss: 0.1053 - val_mean_squared_error: 0.1039
# Epoch 103/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0855 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1064 - mean_squared_error: 0.1051 - val_loss: 0.1051 - val_mean_squared_error: 0.1039
# Epoch 104/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0861 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1066 - mean_squared_error: 0.1054 - val_loss: 0.1050 - val_mean_squared_error: 0.1039
# Epoch 105/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1027 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1064 - mean_squared_error: 0.1054 - val_loss: 0.1049 - val_mean_squared_error: 0.1039
# Epoch 106/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1099 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1065 - mean_squared_error: 0.1054 - val_loss: 0.1049 - val_mean_squared_error: 0.1039
# Epoch 107/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0914 - mean_squared_error: 0.09 - 0s 46us/step - loss: 0.1062 - mean_squared_error: 0.1052 - val_loss: 0.1048 - val_mean_squared_error: 0.1039
# Epoch 108/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1133 - mean_squared_error: 0.11 - 0s 61us/step - loss: 0.1057 - mean_squared_error: 0.1048 - val_loss: 0.1048 - val_mean_squared_error: 0.1039
# Epoch 109/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0962 - mean_squared_error: 0.09 - 0s 49us/step - loss: 0.1057 - mean_squared_error: 0.1048 - val_loss: 0.1047 - val_mean_squared_error: 0.1039
# Epoch 110/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1059 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1058 - mean_squared_error: 0.1049 - val_loss: 0.1047 - val_mean_squared_error: 0.1039
# Epoch 111/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1328 - mean_squared_error: 0.13 - 0s 42us/step - loss: 0.1060 - mean_squared_error: 0.1051 - val_loss: 0.1047 - val_mean_squared_error: 0.1039
# Epoch 112/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1004 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1066 - mean_squared_error: 0.1059 - val_loss: 0.1046 - val_mean_squared_error: 0.1039
# Epoch 113/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1112 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1068 - mean_squared_error: 0.1059 - val_loss: 0.1048 - val_mean_squared_error: 0.1039
# Epoch 114/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1266 - mean_squared_error: 0.12 - 0s 42us/step - loss: 0.1054 - mean_squared_error: 0.1047 - val_loss: 0.1045 - val_mean_squared_error: 0.1039
# Epoch 115/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1276 - mean_squared_error: 0.12 - 0s 54us/step - loss: 0.1062 - mean_squared_error: 0.1055 - val_loss: 0.1045 - val_mean_squared_error: 0.1039
# Epoch 116/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1162 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1056 - mean_squared_error: 0.1050 - val_loss: 0.1044 - val_mean_squared_error: 0.1039
# Epoch 117/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1240 - mean_squared_error: 0.12 - 0s 45us/step - loss: 0.1056 - mean_squared_error: 0.1051 - val_loss: 0.1045 - val_mean_squared_error: 0.1039
# Epoch 118/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1172 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1052 - val_loss: 0.1044 - val_mean_squared_error: 0.1039
# Epoch 119/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1107 - mean_squared_error: 0.11 - 0s 42us/step - loss: 0.1064 - mean_squared_error: 0.1058 - val_loss: 0.1045 - val_mean_squared_error: 0.1039
# Epoch 120/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0941 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1053 - mean_squared_error: 0.1048 - val_loss: 0.1044 - val_mean_squared_error: 0.1039
# Epoch 121/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1045 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1058 - mean_squared_error: 0.1053 - val_loss: 0.1043 - val_mean_squared_error: 0.1039
# Epoch 122/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1161 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1058 - mean_squared_error: 0.1054 - val_loss: 0.1043 - val_mean_squared_error: 0.1039
# Epoch 123/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0998 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1053 - val_loss: 0.1043 - val_mean_squared_error: 0.1039
# Epoch 124/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1003 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1055 - mean_squared_error: 0.1051 - val_loss: 0.1043 - val_mean_squared_error: 0.1039
# Epoch 125/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1121 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1058 - mean_squared_error: 0.1053 - val_loss: 0.1042 - val_mean_squared_error: 0.1039
# Epoch 126/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1240 - mean_squared_error: 0.12 - 0s 45us/step - loss: 0.1054 - mean_squared_error: 0.1050 - val_loss: 0.1043 - val_mean_squared_error: 0.1039
# Epoch 127/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0856 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1055 - mean_squared_error: 0.1052 - val_loss: 0.1042 - val_mean_squared_error: 0.1039
# Epoch 128/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0939 - mean_squared_error: 0.09 - 0s 48us/step - loss: 0.1056 - mean_squared_error: 0.1052 - val_loss: 0.1042 - val_mean_squared_error: 0.1039
# Epoch 129/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0845 - mean_squared_error: 0.08 - 0s 49us/step - loss: 0.1053 - mean_squared_error: 0.1050 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 130/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0796 - mean_squared_error: 0.07 - 0s 46us/step - loss: 0.1051 - mean_squared_error: 0.1048 - val_loss: 0.1042 - val_mean_squared_error: 0.1039
# Epoch 131/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1136 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1055 - mean_squared_error: 0.1051 - val_loss: 0.1043 - val_mean_squared_error: 0.1040
# Epoch 132/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1110 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1053 - mean_squared_error: 0.1050 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 133/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1184 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1053 - mean_squared_error: 0.1050 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 134/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1026 - mean_squared_error: 0.10 - 0s 48us/step - loss: 0.1051 - mean_squared_error: 0.1048 - val_loss: 0.1042 - val_mean_squared_error: 0.1039
# Epoch 135/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1023 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1053 - mean_squared_error: 0.1051 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 136/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0798 - mean_squared_error: 0.07 - 0s 45us/step - loss: 0.1052 - mean_squared_error: 0.1050 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 137/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1273 - mean_squared_error: 0.12 - 0s 46us/step - loss: 0.1052 - mean_squared_error: 0.1050 - val_loss: 0.1042 - val_mean_squared_error: 0.1039
# Epoch 138/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0999 - mean_squared_error: 0.09 - 0s 46us/step - loss: 0.1053 - mean_squared_error: 0.1051 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 139/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1226 - mean_squared_error: 0.12 - 0s 45us/step - loss: 0.1053 - mean_squared_error: 0.1051 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 140/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0957 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1054 - mean_squared_error: 0.1052 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 141/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1053 - mean_squared_error: 0.10 - 0s 48us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 142/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1111 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 143/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0989 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 144/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1029 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1058 - mean_squared_error: 0.1055 - val_loss: 0.1041 - val_mean_squared_error: 0.1039
# Epoch 145/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0946 - mean_squared_error: 0.09 - 0s 105us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 146/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0958 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1044 - mean_squared_error: 0.10 - 0s 126us/step - loss: 0.1052 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 147/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0866 - mean_squared_error: 0.08 - ETA: 0s - loss: 0.1046 - mean_squared_error: 0.10 - 0s 126us/step - loss: 0.1052 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 148/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0991 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1047 - mean_squared_error: 0.10 - 0s 129us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 149/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0959 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1045 - mean_squared_error: 0.10 - 0s 114us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 150/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0943 - mean_squared_error: 0.09 - 0s 40us/step - loss: 0.1053 - mean_squared_error: 0.1052 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 151/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1127 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 152/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0801 - mean_squared_error: 0.08 - 0s 55us/step - loss: 0.1053 - mean_squared_error: 0.1051 - val_loss: 0.1044 - val_mean_squared_error: 0.1042
# Epoch 153/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1147 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1052 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 154/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1142 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1053 - mean_squared_error: 0.1052 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 155/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1195 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1041 - val_mean_squared_error: 0.1040
# Epoch 156/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1041 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 157/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1363 - mean_squared_error: 0.13 - 0s 52us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 158/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1164 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 159/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0897 - mean_squared_error: 0.08 - 0s 46us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 160/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0888 - mean_squared_error: 0.08 - 0s 64us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1041 - val_mean_squared_error: 0.1040
# Epoch 161/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0959 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1051 - mean_squared_error: 0.10 - 0s 133us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 162/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0909 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1045 - mean_squared_error: 0.10 - 0s 124us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 163/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0924 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1046 - mean_squared_error: 0.10 - 0s 129us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 164/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1231 - mean_squared_error: 0.12 - 0s 49us/step - loss: 0.1053 - mean_squared_error: 0.1052 - val_loss: 0.1041 - val_mean_squared_error: 0.1040
# Epoch 165/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1127 - mean_squared_error: 0.11 - 0s 40us/step - loss: 0.1047 - mean_squared_error: 0.1046 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 166/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1121 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 167/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1018 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 168/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1231 - mean_squared_error: 0.12 - 0s 42us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 169/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1111 - mean_squared_error: 0.11 - 0s 51us/step - loss: 0.1049 - mean_squared_error: 0.1048 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 170/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1250 - mean_squared_error: 0.12 - 0s 45us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 171/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1174 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1041 - val_mean_squared_error: 0.1040
# Epoch 172/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0949 - mean_squared_error: 0.09 - 0s 49us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 173/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1041 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 174/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1128 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 175/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1052 - mean_squared_error: 0.10 - 0s 49us/step - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 176/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1080 - mean_squared_error: 0.10 - 0s 48us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 177/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1005 - mean_squared_error: 0.10 - 0s 58us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 178/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1241 - mean_squared_error: 0.12 - ETA: 0s - loss: 0.1046 - mean_squared_error: 0.10 - 0s 147us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 179/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1189 - mean_squared_error: 0.11 - ETA: 0s - loss: 0.1056 - mean_squared_error: 0.10 - 0s 145us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
# Epoch 180/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1085 - mean_squared_error: 0.10 - 0s 81us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 181/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1097 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 182/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1083 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 183/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1119 - mean_squared_error: 0.11 - 0s 42us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 184/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1068 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 185/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1139 - mean_squared_error: 0.11 - 0s 42us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 186/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1139 - mean_squared_error: 0.11 - 0s 42us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 187/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1018 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 188/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1216 - mean_squared_error: 0.12 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 189/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0947 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
# Epoch 190/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0944 - mean_squared_error: 0.09 - 0s 48us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 191/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0998 - mean_squared_error: 0.09 - 0s 42us/step - loss: 0.1049 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 192/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1081 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 193/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1099 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 194/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0987 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1053 - mean_squared_error: 0.1052 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 195/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1084 - mean_squared_error: 0.10 - 0s 48us/step - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1041 - val_mean_squared_error: 0.1040
# Epoch 196/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1260 - mean_squared_error: 0.12 - 0s 48us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 197/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1169 - mean_squared_error: 0.11 - ETA: 0s - loss: 0.1049 - mean_squared_error: 0.10 - 0s 123us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 198/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1155 - mean_squared_error: 0.11 - ETA: 0s - loss: 0.1051 - mean_squared_error: 0.10 - 0s 120us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 199/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0911 - mean_squared_error: 0.09 - 0s 111us/step - loss: 0.1050 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 200/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1040 - mean_squared_error: 0.10 - 0s 70us/step - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 201/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1103 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1054 - mean_squared_error: 0.1054 - val_loss: 0.1040 - val_mean_squared_error: 0.1039
# Epoch 202/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0811 - mean_squared_error: 0.08 - 0s 48us/step - loss: 0.1049 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 203/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0855 - mean_squared_error: 0.08 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 204/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1081 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 205/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0776 - mean_squared_error: 0.07 - 0s 46us/step - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 206/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1072 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 207/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0852 - mean_squared_error: 0.08 - 0s 45us/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 208/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1085 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1052 - mean_squared_error: 0.1051 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
# Epoch 209/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1230 - mean_squared_error: 0.12 - 0s 46us/step - loss: 0.1049 - mean_squared_error: 0.1049 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 210/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1000 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 211/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1012 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1051 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 212/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1068 - mean_squared_error: 0.10 - 0s 49us/step - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 213/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1010 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 214/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1038 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
# Epoch 215/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0964 - mean_squared_error: 0.09 - 0s 48us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 216/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1018 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
# Epoch 217/500
# ...
# Epoch 332/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1153 - mean_squared_error: 0.11 - 0s 61us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1026 - val_mean_squared_error: 0.1026
# Epoch 333/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0949 - mean_squared_error: 0.09 - 0s 49us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1031 - val_mean_squared_error: 0.1030
# Epoch 334/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1402 - mean_squared_error: 0.14 - 0s 55us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1028
# Epoch 335/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1048 - mean_squared_error: 0.10 - 0s 52us/step - loss: 0.1059 - mean_squared_error: 0.1059 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 336/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1096 - mean_squared_error: 0.10 - 0s 48us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1026 - val_mean_squared_error: 0.1026
# Epoch 337/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1174 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 338/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1160 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 339/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1019 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 340/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1027 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1032 - val_mean_squared_error: 0.1031
# Epoch 341/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1042 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 342/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0554 - mean_squared_error: 0.05 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 343/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1019 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1032 - val_mean_squared_error: 0.1032
# Epoch 344/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0899 - mean_squared_error: 0.08 - 0s 55us/step - loss: 0.1059 - mean_squared_error: 0.1059 - val_loss: 0.1026 - val_mean_squared_error: 0.1025
# Epoch 345/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0975 - mean_squared_error: 0.09 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 346/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1086 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 347/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1107 - mean_squared_error: 0.11 - 0s 87us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 348/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1101 - mean_squared_error: 0.11 - ETA: 0s - loss: 0.1042 - mean_squared_error: 0.10 - 0s 127us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1028
# Epoch 349/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1227 - mean_squared_error: 0.12 - ETA: 0s - loss: 0.1070 - mean_squared_error: 0.10 - 0s 132us/step - loss: 0.1059 - mean_squared_error: 0.1059 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 350/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1110 - mean_squared_error: 0.11 - 0s 81us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1032 - val_mean_squared_error: 0.1031
# Epoch 351/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1096 - mean_squared_error: 0.10 - 0s 57us/step - loss: 0.1060 - mean_squared_error: 0.1060 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 352/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1179 - mean_squared_error: 0.11 - 0s 55us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 353/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1203 - mean_squared_error: 0.12 - 0s 48us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 354/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0964 - mean_squared_error: 0.09 - 0s 46us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 355/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1115 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 356/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1203 - mean_squared_error: 0.12 - 0s 49us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1032 - val_mean_squared_error: 0.1032
# Epoch 357/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1017 - mean_squared_error: 0.10 - 0s 45us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 358/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1159 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1030 - val_mean_squared_error: 0.1029
# Epoch 359/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1309 - mean_squared_error: 0.13 - 0s 49us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 360/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0932 - mean_squared_error: 0.09 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1026 - val_mean_squared_error: 0.1026
# Epoch 361/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0962 - mean_squared_error: 0.09 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 362/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1145 - mean_squared_error: 0.11 - 0s 55us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 363/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1122 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1060 - mean_squared_error: 0.1060 - val_loss: 0.1035 - val_mean_squared_error: 0.1034
# Epoch 364/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1263 - mean_squared_error: 0.12 - 0s 45us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 365/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1176 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1024 - val_mean_squared_error: 0.1023
# Epoch 366/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1003 - mean_squared_error: 0.10 - 0s 40us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1028 - val_mean_squared_error: 0.1027
# Epoch 367/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1068 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1033 - val_mean_squared_error: 0.1032
# Epoch 368/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1097 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 369/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1022 - mean_squared_error: 0.10 - 0s 99us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 370/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1242 - mean_squared_error: 0.12 - ETA: 0s - loss: 0.1055 - mean_squared_error: 0.10 - 0s 148us/step - loss: 0.1058 - mean_squared_error: 0.1057 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 371/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1323 - mean_squared_error: 0.13 - ETA: 0s - loss: 0.1065 - mean_squared_error: 0.10 - 0s 135us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 372/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1102 - mean_squared_error: 0.11 - 0s 72us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1027 - val_mean_squared_error: 0.1026
# Epoch 373/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0910 - mean_squared_error: 0.09 - 0s 51us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 374/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1090 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1032 - val_mean_squared_error: 0.1031
# Epoch 375/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1072 - mean_squared_error: 0.10 - 0s 40us/step - loss: 0.1058 - mean_squared_error: 0.1057 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 376/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1187 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 377/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1141 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1026 - val_mean_squared_error: 0.1026
# Epoch 378/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1106 - mean_squared_error: 0.11 - 0s 48us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 379/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1108 - mean_squared_error: 0.11 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 380/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1084 - mean_squared_error: 0.10 - 0s 49us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1026 - val_mean_squared_error: 0.1026
# Epoch 381/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1040 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 382/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1079 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 383/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1018 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 384/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1013 - mean_squared_error: 0.10 - 0s 55us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 385/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0990 - mean_squared_error: 0.09 - 0s 48us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1027 - val_mean_squared_error: 0.1026
# Epoch 386/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1050 - mean_squared_error: 0.10 - 0s 48us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 387/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1008 - mean_squared_error: 0.10 - 0s 88us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 388/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1100 - mean_squared_error: 0.11 - ETA: 0s - loss: 0.1032 - mean_squared_error: 0.10 - 0s 130us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1028 - val_mean_squared_error: 0.1027
# Epoch 389/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0896 - mean_squared_error: 0.08 - ETA: 0s - loss: 0.1070 - mean_squared_error: 0.10 - 0s 145us/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1027 - val_mean_squared_error: 0.1026
# Epoch 390/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1136 - mean_squared_error: 0.11 - ETA: 0s - loss: 0.1055 - mean_squared_error: 0.10 - 0s 117us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1032 - val_mean_squared_error: 0.1032
# Epoch 391/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1091 - mean_squared_error: 0.10 - 0s 64us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 392/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0837 - mean_squared_error: 0.08 - 0s 48us/step - loss: 0.1057 - mean_squared_error: 0.1056 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 393/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1112 - mean_squared_error: 0.11 - 0s 46us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 394/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0898 - mean_squared_error: 0.08 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1026 - val_mean_squared_error: 0.1026
# Epoch 395/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1397 - mean_squared_error: 0.13 - 0s 45us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 396/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1009 - mean_squared_error: 0.10 - 0s 46us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 397/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1099 - mean_squared_error: 0.10 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 398/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1160 - mean_squared_error: 0.11 - 0s 45us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1029 - val_mean_squared_error: 0.1029
# Epoch 399/500
# 666/666 [==============================] - ETA: 0s - loss: 0.0878 - mean_squared_error: 0.08 - 0s 43us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 400/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1098 - mean_squared_error: 0.10 - 0s 42us/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 401/500
# 666/666 [==============================] - ETA: 0s - loss: 0.1260 - mean_squared_error: 0.12 - ETA: 0s - loss: 0.1063 - mean_squared_error: 0.10 - 0s 120us/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.1028 - val_mean_squared_error: 0.1027
# Epoch 402/500
# 576/666 [========================>.....] - ETA: 0s - loss: 0.0998 - mean_squared_error: 0.09 - ETA: 0s - loss: 0.1073 - mean_squared_error: 0.10

# %% [markdown]
# #### Display the results for ANN

# %%
Results_ANN = pd.DataFrame(Results_ANN_list, columns=['Number of nodes', 'Number of layers', 'Dropout rate',
                                                      'Number of epochs', 'Regularization penalty', 'R2_ANN',
                                                      'MSE_ANN'])
Results_ANN.sort_values(['R2_ANN'], ascending = False)

# %% [markdown]
# ## Regression
# This method takes as parameter the degree: **degree**, of the polynomial function to be fitted.

# %%
# Evaluate performance of regression models over different degrees

degree_range_regression = 6

Results_regression = []

plt.figure(figsize=(12, 10))
for degree in range(2, degree_range_regression):
    R2_regression, MSE_regression = Regression(X, y, sensor_name, score_name, degree,
                                               'plot')
    Results_regression.append([degree, R2_regression, MSE_regression])

# %% [markdown]
# #### Display the results for Regression

# %%
Results_regression = pd.DataFrame(Results_regression, columns=['degree', 'R2_regression', 'MSE_regression'])

Results_regression.sort_values(['R2_regression'], ascending = False)
# Out:
#    degree  R2_regression  MSE_regression
# 2       4       0.939776        0.078043
# 3       5       0.939146        0.078450
# 1       3       0.936808        0.079943
# 0       2       0.898541        0.101296

# %% [markdown]
# ## Spline Regression
# This method takes as parameter the degree: **degree**, of the polynomial function to be fitted and points of division of the series: **quantiles**.

# %%
degree_range_spline = 6
quantiles_in_spline_regression = (0.25, 0.5, 0.75)

Results_splines = []

plt.figure(figsize=(12, 10))
for degree in range(2, degree_range_spline):
    R2_spline, MSE_spline = Spline_Regression(X, y, sensor_name, score_name, degree,
                                              quantiles_in_spline_regression, 'plot')
    Results_splines.append([degree, R2_spline, MSE_spline])

# %% [markdown]
# #### Display the results for Splines

# %%
Results_splines = pd.DataFrame(Results_splines, columns=['degree', 'R2_spline', 'MSE_spline'])

Results_splines.sort_values(['R2_spline'], ascending = False)
# Out:
#    degree  R2_spline  MSE_spline
# 3       5   0.940681    0.077454
# 2       4   0.940041    0.077871
# 1       3   0.939792    0.078032
# 0       2   0.939420    0.078273
