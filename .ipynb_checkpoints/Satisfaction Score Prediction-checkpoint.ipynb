# %% [markdown]
# # Import necessary packages

# %%
# Start Python Imports
import math

# Data Manipulation
import numpy as np
import pandas as pd
import statsmodels
from scipy.stats import pearsonr, normaltest, jarque_bera, spearmanr, f_oneway, ttest_ind
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white
import statsmodels.api as sm
from statsmodels.stats.power import tt_ind_solve_power, TTestIndPower
from satisfaction_score_data_generator import generate_dataset_with_sensor_readings_and_satisfaction_scores

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn import preprocessing
from sklearn.utils import shuffle
from keras.layers import Dropout
from keras import regularizers

# Fitting a model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# Neural Network
from keras.models import Sequential
from keras.layers import Dense

# Evaluation
from sklearn.metrics import mean_squared_error, r2_score
from patsy.highlevel import dmatrix
from tqdm import tqdm

# Ignore warnings
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Analysis
#
# ### Data Generation
#
# In order to generate the Synthetic Data for the analasys
#
# 1. Indicate the number od samples to generate
# 2. Choose type of a wavelet used for smoothing generated fucntion (i.e. db2, db4, db6, db8...etc.)
# 3. Indicate a value of standard deviation of the gausian noise added to the generated data

# %%
# Generate dataset with the scores and reading using satisfaction_score_data_generator.py
sample_size = 50
noise_standard_deviation = 0.03
wavelet = 'db8'

satisfaction_vs_sensors = generate_dataset_with_sensor_readings_and_satisfaction_scores(sample_size,
                                                                                        noise_standard_deviation,
                                                                                        wavelet)

# %% [markdown]
# ## Display summary statistics

# %%
satisfaction_vs_sensors.describe()
# Out:
#        sensor_temperature  sensor_humidity  sensor_heat_index   sensor_air  \
# count           50.000000        50.000000          50.000000    50.000000
# mean            24.229774        59.942638          25.256016  1224.706421
# std              4.759965        19.755033           6.493995   526.252625
# min             15.622293        20.496138          14.109520   250.104507
# 25%             20.048474        44.774990          19.143841   747.314468
# 50%             24.612077        64.847965          25.127569  1360.860840
# 75%             28.295653        76.665342          30.033630  1689.980835
# max             31.835678        84.838104          39.746067  1988.621094
#
#        sensor_light  sensor_noise  comfort_score_temperature  \
# count     50.000000     50.000000                  50.000000
# mean     804.448730     54.907604                   0.434643
# std      400.869843     12.783633                   0.260156
# min      215.783188     30.672951                   0.043127
# 25%      420.229828     44.496658                   0.205347
# 50%      780.567627     56.139034                   0.406335
# 75%     1105.505035     63.251185                   0.576785
# max     1486.539795     74.703575                   0.998778
#
#        comfort_score_humidity  comfort_score_heat_index  comfort_score_air  \
# count               50.000000                 50.000000          50.000000
# mean                 0.676835                  0.404691           0.459818
# std                  0.233991                  0.245898           0.336964
# min                  0.236110                  0.098586           0.104312
# 25%                  0.491528                  0.181596           0.167263
# 50%                  0.726225                  0.336114           0.317681
# 75%                  0.879687                  0.585086           0.833950
# max                  0.988474                  0.883273           0.988474
#
#        comfort_score_light  comfort_score_noise
# count            50.000000            50.000000
# mean              0.610714             0.655566
# std               0.260988             0.307011
# min               0.160045             0.087673
# 25%               0.305307             0.439105
# 50%               0.675853             0.735042
# 75%               0.863938             0.931606
# max               0.961125             0.988474

# %% [markdown]
# ### Plot the correlation matrix

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(satisfaction_vs_sensors.corr(), cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# ### Data distribution plots
#
# Generated data distribution is visualised by using a boxplot and ploting a univariate distribution of observations.

# %%
no_of_columns = np.shape(satisfaction_vs_sensors)[1]
measurements = satisfaction_vs_sensors.columns.values

plt.figure(figsize=(4.5*no_of_columns,5*no_of_columns))
for i in range(0,len(measurements)):
    plt.subplot(no_of_columns + 1, no_of_columns, i + 1)
    sns.distplot(satisfaction_vs_sensors[measurements[i]],kde=True)

# %%
plt.figure(figsize=(no_of_columns,5*no_of_columns))
for i in range(0,len(measurements)):
    plt.subplot(no_of_columns + 1, no_of_columns, i + 1)
    sns.boxplot(satisfaction_vs_sensors[measurements[i]],color='lightblue',orient='v')
    plt.tight_layout()

# %% [markdown]
# ### Divide the dataset into predictors and outcome
#
# In orther to perform predicitons and further analysis, a measurement of interest has to be extracted from the generated dataset and divided into predictors (independent variable X) and outcome (dependent variable y).
#
# The name of the measurement/score of interest can be specified by assigning a string value to the variable ***measurement_name*** from:
#     * temperature
#     * humidity
#     * heat_index
#     * air
#     * light
#     * noise

# %%
# Specify the name of the measurement/score of interest

measurement_name = 'air'
# measurement_name2 = 'humidity'
# measurement_name3 = 'heat_index'
sensor_name = f'sensor_{measurement_name}'
score_name = f'comfort_score_{measurement_name}'
# sensor_name2 = f'sensor_{measurement_name2}'
# score_name2 = f'comfort_score_{measurement_name3}'

# Divide the dataset into predictors and outcome

X = satisfaction_vs_sensors[[sensor_name]]
# X = satisfaction_vs_sensors[[sensor_name, sensor_name2]]
y = satisfaction_vs_sensors[[score_name]]

# %% [markdown]
# ### Visualise the variables
#
# In order to visualise the data correctly by plotting the result of the prediction model or to plot the original data a funtion **Function sort_for_plotting** is used to sort the values before plotting

# %%
def sort_for_plotting(X, y):
    data_set = np.column_stack((X, y))
    test_set_sorted = data_set[data_set[:, 0].argsort()]
    X_sorted = test_set_sorted[:, 0]
    y_sorted = test_set_sorted[:, 1]

    return X_sorted, y_sorted

# %%
# Plot the original data
X_sorted, y_sorted = sort_for_plotting(X, y)

plt.figure(figsize=(12, 10))
plt.plot(X_sorted, y_sorted)
plt.show()

# %% [markdown]
# ### Jarque-Bera Test
#
# Data is checked for normal distribution. If a variable doesn't have a normal distrubution, a logarithmic transformation is applied and tested.
#
# H0: Data is normally distributed
#
# H1: Skewness and kurtosis doesn't match a normal distribution
#
# H0 is rejected when p-value < 0.05

# %%
statistics_jb_X, p_value_jb_X = jarque_bera(X)
statistics_jb_y, p_value_jb_y = jarque_bera(y)

# Plot variable to examine its distribution
sns.distplot(y) 

# If the variable doesn't have a normal distribution check if it has log-normal distribution
X_log = np.log(X)
y_log = np.log(X_log)

statistics_jb_X_log, p_value_jb_X_log = jarque_bera(X_log)
statistics_jb_y_log, p_value_jb_y_log = jarque_bera(y_log) 

# Plot a transformed variable to examine its distribution
sns.distplot(y_log) 

print(f'Jarque-Bera Test for X: statistics = {statistics_jb_X}; p-value = {p_value_jb_X}')
print(f'Jarque-Bera Test for y: statistics = {statistics_jb_y}; p-value = {p_value_jb_y}')

print(f'Jarque-Bera Test for X_log: statistics = {statistics_jb_X_log}; p-value = {p_value_jb_X_log}')
print(f'Jarque-Bera Test for y_log: statistics = {statistics_jb_y_log}; p-value = {p_value_jb_y_log}')
# Out:
# Jarque-Bera Test for X: statistics = 3.8333083955106257; p-value = 0.14709830153722403
# Jarque-Bera Test for y: statistics = 6.471156959298406; p-value = 0.03933744244701409
# Jarque-Bera Test for X_log: statistics = 10.021299781229853; p-value = 0.006666569357252405
# Jarque-Bera Test for y_log: statistics = 13.153602871380693; p-value = 0.001392295527046672

# %% [markdown]
# ### Spearman and Pearson test for correlation
#
# Pearson correlation coefficient assumes a normal distribution. When a variable is not normally distributed use Spearman's rank correlation.
#
# H0: There is no correlation
#
# H1: Correlation coefficient is statistically significant

# %%
rho, p_value_spearman = spearmanr(X, y)
r, p_value_pearson = pearsonr(X.iloc[:, 0], y.iloc[:, 0])

print(f'Correlation Spearman = {rho}, p-value = {p_value_spearman}')
print(f'Correlation Pearson = {r}, p-value = {p_value_pearson}')
# Out:
# Correlation Spearman = -0.9299623042849595, p-value = 1.6997338679287265e-22
# Correlation Pearson = -0.9608551275351, p-value = 2.0824271889288736e-28

# %% [markdown]
# ### Statistical power for regression
#
# Power is genarlly estimating a probablity that the regression finding is statistically significant.
# For instance, having 90% power means that 90% of samples collected from the same population will demonstrate a significant relationship (H0 is rejected).
#
# Power can be determined by calculating L value, which is a non-centrality parameter and reading the value from the table below for a given number of predictors $k$.
#
# ![image.png](attachment:image.png)
#
# Cohen, J. (2013). Statistical power analysis for the behavioral sciences. Routledge.

# %%
# Set parameters to perform the test
R2_regression = 0.6
number_of_predictors_degrees = 3
sample_size = 10

# Effect size can be calculated using the R2 statistic 
cohen_effect_size = R2_regression / (1 - R2_regression)
# squared_correlation_coefficient_effect_size = r**2

L_value_non_centrality_parameter = cohen_effect_size * (sample_size - number_of_predictors_degrees - 1)

# Read the power from the table based on non centrality parameter
L_value_non_centrality_parameter
# Out:
# 8.999999999999998

# %%
# Set parameters to perform the test
R2_regression = 0.4
number_of_predictors_degrees = 3

# Read from the tables e.g. for 80% power and 3 predictors the value is:
L_value = 10.9

# Effect size can be calculated using the R2 statistic 
cohen_effect_size = R2_regression / (1 - R2_regression)

estimated_sample_size = (L_value / cohen_effect_size) + number_of_predictors_degrees + 1
estimated_sample_size
# Out:
# 20.349999999999998

# %% [markdown]
# ### Size of a sample needed
# One-sample t-test is another method to determine the sample size given the needed test power, significance level and the effect size (or to determine the power).

# %%
# Set parameters to perform the test, put "None" by the parameter that is needed to be calculated
R2_regression = 0.4
effect_size = R2_regression / (1 - R2_regression)
number_of_observations = None
significance = 0.05
test_power = 0.9

power_test = smp.TTestPower().solve_power(effect_size=effect_size, nobs=number_of_observations, alpha=significance,
                                    power = test_power, alternative='larger')

print(f'Sample Size: {power_test}') 
# all the results give a very small sample 
# Maybe square of the Pearson correlation coefficient would be better as an effect size - size of a sample is huge
# Out:
# Sample Size: 20.699143325387332

# %% [markdown]
# ### Power plots
#
# Plots presented below allow see how the power changes with number of observations and effect size

# %%
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(2,1,1)
fig=smp.TTestPower().plot_power(dep_var='nobs',
                                  nobs= np.arange(2, 120),
                                  effect_size=np.array([0.4, 0.6, 0.8, 1, 1.5, 2]),
                                  alternative='larger',
                                  ax=ax, title='T-Test Power')
ax = fig.add_subplot(2,1,2)
fig=smp.TTestPower().plot_power(dep_var='es',
                                  nobs=np.array([10, 20, 40, 60, 80, 100]),
                                  effect_size=np.linspace(0.1, 2),
                                  alternative='larger',
                                  ax=ax, title='')

# %% [markdown]
# ### Ordinary Least Squares (OLS) model
#
# Summary statistics for the OLS displayes the R-squared that shows how well the data fits the model.
#
# F-statistic that measures the significance of the fit and T-statistics measures the significance of the estimated coefficients.
#
# F-statistic:
#
#     H0: All of the regression coefficients are equal to zero
#
#     H1: Model has good predictive capability
#
# T-statistics:
#
#     H0: Variable is not signoificant to the model
#
#     H1: Significant relationship between the response and explanatory variables
#
#
# In terms of the model residual distribution, Jarque-Bera Test for the normality

# %%
degree = 3

# Perform polynomial transformation
polynomial_features = PolynomialFeatures(degree=degree)
X_polynomial = polynomial_features.fit_transform(X_log)

# Fit the model
model = sm.OLS(y, X_polynomial).fit()
y_predicted = model.predict(X_polynomial)

slope, intercept = np.polyfit(np.log(X.iloc[:, 0]), np.log(y.iloc[:, 0]), 1)

# Plot the prediction
plt.scatter(X,y)
X_sorted, y_sorted_p = sort_for_plotting(X, y_predicted)
plt.plot(X_sorted, y_sorted_p)
plt.show()

# Show summary statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      comfort_score_air   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     464.6
# Date:                Mon, 28 Oct 2019   Prob (F-statistic):           2.17e-34
# Time:                        15:36:43   Log-Likelihood:                 70.038
# No. Observations:                  50   AIC:                            -132.1
# Df Residuals:                      46   BIC:                            -124.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -98.5369     14.923     -6.603      0.000    -128.575     -68.499
# x1            44.5641      6.849      6.507      0.000      30.778      58.350
# x2            -6.5502      1.042     -6.285      0.000      -8.648      -4.452
# x3             0.3150      0.053      5.989      0.000       0.209       0.421
# ==============================================================================
# Omnibus:                        0.124   Durbin-Watson:                   2.259
# Prob(Omnibus):                  0.940   Jarque-Bera (JB):                0.332
# Skew:                          -0.008   Prob(JB):                        0.847
# Kurtosis:                       2.601   Cond. No.                     6.71e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Test for Heteroskedasticity
#
# H0: Homoskedasticity
#
# H1: Heteroskedasticity

# %%
bp_test = het_breuschpagan(model.resid, X_polynomial)
white_test = het_white(model.resid,  model.model.exog)

labels = ['Lagrange Multiplier Statistic', 'Lagrange Multiplier-Test p-value', 'F-Statistic', 'F-Test p-value']

print(dict(zip(labels, bp_test)))
print(dict(zip(labels, white_test)))
# Out:
# {'Lagrange Multiplier Statistic': 4.822748556138717, 'Lagrange Multiplier-Test p-value': 0.18524609311161674, 'F-Statistic': 1.6368594553836064, 'F-Test p-value': 0.19384832808780383}
# {'Lagrange Multiplier Statistic': 11.60123850031397, 'Lagrange Multiplier-Test p-value': 0.07147931511472638, 'F-Statistic': 2.1652315336506347, 'F-Test p-value': 0.06515489080046992}

# %% [markdown]
# ## ANOVA Test
#
# The ANOVA test has important assumptions that must be satisfied in order for the associated p-value to be valid.
#
# 1. The samples are independent.
# 2. Each sample is from a normally distributed population.
# 3. The population standard deviations of the groups are all equal. This property is known as homoscedasticity.
#
# H0: $\mu_1 = \mu_2$
#
# H1: $\mu_1 \neq \mu_2$

# %%
# F_statistic, p_value_anova = f_oneway(X, y)

# print(f'ANOVA F-statistic = {F_statistic}, p-value = {p_value_anova}')

# Compute ANOVA
# anova_results = pg.anova(dv=score_name, between=sensor_name, data=satisfaction_vs_sensors_sorted)

# pg.print_table(anova_results)

# %% [markdown]
# ### T-test for the means of two independent samples of scores.
#
# H0: $\mu_1 = \mu_2$
#
# H1: $\mu_1 \neq \mu_2$

# %%
# t_statistics, p_value_t = ttest_ind(X, y)

# %% [markdown]
# # Model Fitting
#
# After performing statistical analysis on the generated data five models were implemented and tested for preduiction accuracy

# %% [markdown]
# ## Regression

# %%
def Regression(X, y, sensor_name: str, score_name: str, degree, plot: str):
    """
    :param X: array of independent variables
    :param y: array of dependent variable
    :param sensor_name: name of the sensor user for plots
    :param score_name: name of the satisfaction score used for plots
    :param degree: degree of the polynomial
    :param plot: takes values 'plot' to plot the functions and 'show' to plot and display
    """

    # degree: determine the degrees of the polynomial function to be fitted and tested
    # degree = 1 will result in fitting a Linear Regression to the data

    # Split the generated dataset into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1 / 3, random_state=42, shuffle=True)

    polynomial_transformation = PolynomialFeatures(degree=degree)

    # Fit polynomial regression
    X_polynomial = polynomial_transformation.fit_transform(X_train)
    polynomial_regression = LinearRegression().fit(X_polynomial, y_train)

    # Predict the satisfaction score
    y_predicted = polynomial_regression.predict(polynomial_transformation.fit_transform(X_test))

    X_test_sorted, y_predicted_sorted = sort_for_plotting(X_test, y_predicted)

    # Validate model
    MSE_regression = math.sqrt(mean_squared_error(y_test, y_predicted))
    R2_regression = r2_score(y_test, y_predicted)

    def plot_regression():
        # Plot original data
        plt.scatter(X_test, y_test, color='red')
        # Plot predicted regression function
        plt.plot(X_test_sorted, y_predicted_sorted, label=f"Degree {deg}" + f" $R^2$: {round(R2_regression, 3)}")
        plt.legend(loc='upper right')
        plt.xlabel(f"{sensor_name}")
        plt.ylabel(f"{score_name}")
        plt.title(f'Satisfaction vs indoor conditions (Polynomial Regression)')
        return

    if plot == 'plot':
        plot_regression()
    if plot == 'show':
        plot_regression()
        plt.show()
    return R2_regression, MSE_regression

# %% [markdown]
# ## Spline Regression

# %%
def Spline_Regression(X, y, sensor_name: str, score_name: str, degree, quantiles, plot):
    """
    :param X: array of independent variables
    :param y: array of dependent variable
    :param sensor_name: name of the sensor user for plots
    :param score_name: name of the satisfaction score used for plots
    :param degree: degree of the polynomial
    :param quantiles: points of division of the series
    :param plot: takes values 'plot' to plot the functions and 'show' to plot and display
    """

    knots_array = np.quantile(X, quantiles)
    knots = tuple(knots_array)

    # Split the generated dataset into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1 / 3, random_state=42, shuffle=True)

    # Generating cubic spline with 4 knots
    X_reshaped = dmatrix(f"bs(train, knots = {knots}, degree = {degree}, include_intercept = False)",
                         {"train": X_train}, return_type='dataframe')

    # Fitting Generalised linear model on transformed dataset
    spline_regression = LinearRegression().fit(X_reshaped, y_train)

    # Predict the satisfaction score
    y_predicted = spline_regression.predict(
        dmatrix(f"bs(test, knots = {knots},degree = {degree}, include_intercept = False)", {"test": X_test},
                return_type='dataframe'))

    X_test_sorted, y_predicted_sorted = sort_for_plotting(X_test, y_predicted)

    # Validate model
    R2_spline = r2_score(y_test, y_predicted)
    MSE_spline = math.sqrt(mean_squared_error(y_test, y_predicted))

    def plot_spline_regression():
        # Plot original data
        plt.scatter(X_test, y_test, color='red')
        # Plot predicted regression function
        plt.plot(X_test_sorted, y_predicted_sorted, label=f"Degree {degree} with {len(quantiles)} knots" + f"$R^2$: {round(R2_spline, 3)}")
        plt.legend()
        plt.title('Satisfaction vs indoor conditions (Spline Regression)')
        plt.xlabel(f'{sensor_name}')
        plt.ylabel(f'{score_name}')
        # plt.show()
        return

    if plot == 'plot':
        plot_spline_regression()
    if plot == 'show':
        plot_spline_regression()
        plt.show()
    return R2_spline, MSE_spline

# %% [markdown]
# ## Random Forest Regression

# %%
def Random_Forest_Regression(X, y, max_depth, n_estimators, plot):
    """
    :param X: array of independent variables
    :param y: array of dependent variable
    :param max_depth: maximum depth of the tree
    :param n_estimators: number of trees in the forest.
    :param plot: takes values 'plot' to plot the functions and 'show' to plot and display
    """

    # Split the generated dataset into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1 / 3, random_state=42, shuffle=True)

    random_forest_regression = RandomForestRegressor(max_depth=max_depth, random_state=0, n_estimators=n_estimators)

    random_forest_regression.fit(X_train, y_train)

    y_predicted = random_forest_regression.predict(X_test)

    X_test_sorted, y_predicted_sorted = sort_for_plotting(X_test, y_predicted)

    # Validate model
    R2_random_forest = r2_score(y_test, y_predicted)
    MSE_random_forest = math.sqrt(mean_squared_error(y_test, y_predicted))

    def plot_random_forest():
        # Plot original data
        plt.scatter(X_test, y_test, color='red')
        # Plot predicted regression function
        plt.plot(X_test_sorted, y_predicted_sorted, label=f"Depth {max_depth} with {n_estimators} trees" +
                                                          f" $R^2$: {round(R2_random_forest, 3)}")
        plt.legend(loc='upper right')
        plt.xlabel(f"{sensor_name}")
        plt.ylabel(f"{score_name}")
        plt.title(f'Satisfaction vs indoor conditions (Random Forest Regression)')
        return

    if plot == 'plot':
        plot_random_forest()
    if plot == 'show':
        plot_random_forest()
        plt.show()
    return R2_random_forest, MSE_random_forest

# %% [markdown]
# ## Decision Tree Regression

# %%
def Decision_Tree_Regression(X, y, max_depth, n_estimators, plot):
    """
    :param X: array of independent variables
    :param y: array of dependent variable
    :param max_depth: maximum depth of the tree
    :param n_estimators: maximum number of estimators at which boosting is terminated
    :param plot: takes values 'plot' to plot the functions and 'show' to plot and display
    """

    # Split the generated dataset into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1 / 3, random_state=42)

    boost_decision_tree_regression = AdaBoostRegressor(DecisionTreeRegressor(max_depth=max_depth),
                                                       n_estimators=n_estimators)

    boost_decision_tree_regression.fit(X_train, y_train)

    y_predicted = boost_decision_tree_regression.predict(X_test)

    X_test_sorted, y_predicted_sorted = sort_for_plotting(X_test, y_predicted)

    # Validate model
    R2_decision_tree = r2_score(y_test, y_predicted)
    MSE_decision_tree = math.sqrt(mean_squared_error(y_test, y_predicted))

    def plot_decision_tree():
        # Plot original data
        plt.scatter(X_test, y_test, color='red')
        # Plot predicted regression function
        plt.plot(X_test_sorted, y_predicted_sorted, label=f"Depth {max_depth} with {n_estimators} estimators" +
                                                          f" $R^2$: {round(R2_decision_tree, 3)}")
        plt.legend(loc='upper right')
        plt.xlabel(f"{sensor_name}")
        plt.ylabel(f"{score_name}")
        plt.title(f'Satisfaction vs indoor conditions (Random Forest Regression)')
        return

    if plot == 'plot':
        plot_decision_tree()
    if plot == 'show':
        plot_decision_tree()
        plt.show()
    return R2_decision_tree, MSE_decision_tree

# %% [markdown]
# ## Artificial Neural Network

# %%
def ANN(X, y, number_of_nodes, number_of_layers, dropout_rate, number_of_epochs, regularization_penalty, plot):
    """
    :param X: array of independent variables
    :param y: array of dependent variable
    :param number_of_nodes: number of neurons
    :param number_of_layers: number of layers
    :param dropout_rate: fraction rate between 0 and 1 of the input units to drop
    :param number_of_epochs: number of training iterations
    :param regularization_penalty: regularization penalty on layer parameters during optimization
    :param plot: takes values 'plot' to plot the functions and 'show' to plot and display
    """
    layers_parameters = [number_of_nodes] * number_of_layers

    scaler = preprocessing.StandardScaler()
    X_standarized = scaler.fit_transform(X)

    # Shuffle the previously sorted dataset - in ANN ordered data impairs learning
    X_standarized_shuffle, y_shuffle = shuffle(X_standarized, y)

    # Split the generated dataset into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X_standarized_shuffle, y_shuffle, test_size=1 / 3,
                                                        random_state=42, shuffle=True)
    input_size = X.shape[1]

    # Create a model with 2 hidden layers and 32 neurons using Rectified Linear Unit Activation Function
    # Add regularization (L2 - norm) and dropout to fight overfitting

    def create_model(layers_parameters):
        model = Sequential()
        model.add(
            Dense(layers_parameters[0], activation='relu', kernel_regularizer=regularizers.l2(regularization_penalty),
                  input_dim=input_size))
        model.add(Dropout(dropout_rate))

        for neuron_number in layers_parameters[1:]:
            model.add(
                Dense(neuron_number, activation='relu', kernel_regularizer=regularizers.l2(regularization_penalty)))
            model.add(Dropout(dropout_rate))

        model.add(Dense(input_size, activation='relu', kernel_regularizer=regularizers.l2(regularization_penalty)))
        return model

    model = create_model(layers_parameters)

    model.compile(optimizer='adam',
                  loss='mean_squared_error',
                  metrics=['mean_squared_error'])

    training_history = model.fit(X_train, y_train,
                                 batch_size=32, epochs=number_of_epochs,
                                 validation_data=(X_test, y_test))

    y_predicted = model.predict(X_test, batch_size=32, verbose=0)

    X_test_sorted, y_predicted_sorted = sort_for_plotting(X_test, y_predicted)

    MSE_ANN = model.evaluate(X_test, y_test)[1]

    R2_ANN = r2_score(y_test, y_predicted)

    # predicted_set = np.c_[X_standarized, y_predicted]

    def plot_artificial_neural_network():
        plt.figure(figsize=(12, 10))
        # Plot original data
        plt.scatter(scaler.inverse_transform(X_test), y_test, color='red')
        # Plot predicted regression function
        plt.plot(scaler.inverse_transform(X_test_sorted), y_predicted_sorted,
                 label=f"Dropout {dropout_rate} with {number_of_epochs} epochs and {regularization_penalty} penalty, " +
                       f"Nodes: {number_of_nodes}, Layers: {number_of_layers}, " + f"$R^2$: {round(R2_ANN, 3)}")
        plt.legend()
        plt.title('Satisfaction vs indoor conditions (ANN)')
        plt.xlabel(f'{sensor_name}')
        plt.ylabel(f'{score_name}')

        # plt.plot(training_history.history['mean_squared_error'])
        # plt.plot(training_history.history['val_mean_squared_error'])
        # plt.title('Model Error')
        # plt.ylabel('MSE')
        # plt.xlabel('Epoch')
        # plt.legend(['Train', 'Test'])
        # plt.show()

    if plot == 'plot':
        plot_artificial_neural_network()
    if plot == 'show':
        plot_artificial_neural_network()
        plt.show()

    return R2_ANN, MSE_ANN, training_history

# %% [markdown]
# # Model Testing
#
# All the methods are tested over various parameters in order to find the best set.

# %% [markdown]
# ## Random Forest
#
# This method takes as parameters maximum depth of the tree: **max_depth** and number of trees in the forest: **n_estimators**

# %%
max_depth = [4, 5, 6]
n_estimators = [10, 50, 100, 200]
Results_Random_Forest_list = []

plt.figure(figsize=(12, 10))

for depth in tqdm(max_depth):
    for estimator in n_estimators:
        R2_random_forest, MSE_random_forest = Random_Forest_Regression(X, y, depth, estimator, 'plot')
        Results_Random_Forest_list.append([depth, estimator, R2_random_forest, MSE_random_forest])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  5.14it/s]

# %% [markdown]
# #### Display the results for Random Forest
# Results of the testing are displayed in the table below, sorted accoding to R2.

# %%
Results_Random_Forest = pd.DataFrame(Results_Random_Forest_list, columns=['max_depth', 'n_estimators',
                                                                     'R2_random_forest', 'MSE_random_forest'])
Results_Random_Forest.sort_values(['R2_random_forest'], ascending = False)
# Out:
#     max_depth  n_estimators  R2_random_forest  MSE_random_forest
# 1           4            50          0.978952           0.051173
# 5           5            50          0.978455           0.051773
# 9           6            50          0.978287           0.051974
# 0           4            10          0.977646           0.052736
# 3           4           200          0.977117           0.053356
# 7           5           200          0.976602           0.053953
# 8           6            10          0.976519           0.054049
# 4           5            10          0.976507           0.054063
# 11          6           200          0.976409           0.054175
# 2           4           100          0.975694           0.054990
# 6           5           100          0.975263           0.055475
# 10          6           100          0.975127           0.055628

# %% [markdown]
# ## Boosted Decision Tree Regression
#
# This method takes as parameters maximum depth of the tree: **max_depth** and maximum number of estimators at which boosting is terminated: **n_estimators**

# %%
max_depth = [4, 5, 6]
n_estimators = [10, 50, 100, 200]
Results_Decision_Tree_list = []

plt.figure(figsize=(12, 10))
for depth in tqdm(max_depth):
    for estimator in n_estimators:
        R2_decision_tree, MSE_decision_tree = Decision_Tree_Regression(X, y, depth, estimator, 'plot')
        Results_Decision_Tree_list.append([depth, estimator, R2_decision_tree, MSE_decision_tree])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.74it/s]

# %% [markdown]
# #### Display the results for Boosted Decision Tree

# %%
Results_Decision_Tree = pd.DataFrame(Results_Decision_Tree_list, columns=['max_depth', 'n_estimators',
                                                                          'R2_decision_tree', 'MSE_decision_tree'])
Results_Decision_Tree.sort_values(['R2_decision_tree'], ascending=False)
# Out:
#     max_depth  n_estimators  R2_decision_tree  MSE_decision_tree
# 6           5           100          0.966053           0.064987
# 0           4            10          0.965756           0.065271
# 1           4            50          0.965585           0.065433
# 5           5            50          0.965570           0.065448
# 11          6           200          0.965490           0.065523
# 3           4           200          0.965461           0.065551
# 7           5           200          0.965179           0.065819
# 4           5            10          0.965076           0.065916
# 10          6           100          0.964811           0.066165
# 9           6            50          0.964466           0.066489
# 2           4           100          0.964460           0.066494
# 8           6            10          0.963929           0.066990

# %% [markdown]
# ## Artificial Neural Networks
#
# This method takes as parameters number of nodes (neurons): **number_of_nodes** and layers: **number_of_layers** in the Neural Network architecture. In order to reduce overfitting dropout and regularization are applied. Variables **dropout_rate** and **regularization_penalty** introduce the necessary modifications. Lastly, the number of training iterations is determined by parameter: **number_of_epochs**.

# %%
# Chose the number of neurons and number of hidden layers and a dropout rate

number_of_nodes = [30, 50, 100]
number_of_layers = [2, 10, 100]
dropout_rate = [0.1, 0.2]
number_of_epochs = [500, 1000]
regularization_penalty = [0.1, 0.001, 0.0001]
Results_ANN_list = []

# Fit ANN model

plt.figure(figsize=(12, 10))

for nodes in tqdm(number_of_nodes):
    for layers in number_of_layers:
        for dropout in dropout_rate:
            for epochs in number_of_epochs:
                for regularization in regularization_penalty:
                    R2_ANN, MSE_ANN, training_history = ANN(X, y, nodes, layers, dropout, epochs, regularization,
                                                            'plot')
                    Results_ANN_list.append([nodes, layers, dropout, epochs, regularization, R2_ANN, MSE_ANN])
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# Train on 6 samples, validate on 4 samples
# Epoch 1/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4764 - mean_squared_error: 0.4659 - val_loss: 0.7163 - val_mean_squared_error: 0.7059
# Epoch 2/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4763 - mean_squared_error: 0.4659 - val_loss: 0.7161 - val_mean_squared_error: 0.7059
# Epoch 3/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4761 - mean_squared_error: 0.4659 - val_loss: 0.7159 - val_mean_squared_error: 0.7059
# Epoch 4/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4760 - mean_squared_error: 0.4659 - val_loss: 0.7158 - val_mean_squared_error: 0.7059
# Epoch 5/500
# 6/6 [==============================] - 0s 665us/step - loss: 0.4758 - mean_squared_error: 0.4659 - val_loss: 0.7156 - val_mean_squared_error: 0.7059
# Epoch 6/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.4756 - mean_squared_error: 0.4659 - val_loss: 0.7155 - val_mean_squared_error: 0.7059
# Epoch 7/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.4755 - mean_squared_error: 0.4659 - val_loss: 0.7153 - val_mean_squared_error: 0.7059
# Epoch 8/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.4735 - mean_squared_error: 0.4640 - val_loss: 0.7152 - val_mean_squared_error: 0.7059
# Epoch 9/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.4752 - mean_squared_error: 0.4659 - val_loss: 0.7150 - val_mean_squared_error: 0.7059
# Epoch 10/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4744 - mean_squared_error: 0.4653 - val_loss: 0.7144 - val_mean_squared_error: 0.7054
# Epoch 11/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4749 - mean_squared_error: 0.4659 - val_loss: 0.7139 - val_mean_squared_error: 0.7050
# Epoch 12/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4748 - mean_squared_error: 0.4659 - val_loss: 0.7137 - val_mean_squared_error: 0.7049
# Epoch 13/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.4743 - mean_squared_error: 0.4655 - val_loss: 0.7139 - val_mean_squared_error: 0.7052
# Epoch 14/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.4727 - mean_squared_error: 0.4641 - val_loss: 0.7138 - val_mean_squared_error: 0.7053
# Epoch 15/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4722 - mean_squared_error: 0.4637 - val_loss: 0.7139 - val_mean_squared_error: 0.7055
# Epoch 16/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.4719 - mean_squared_error: 0.4635 - val_loss: 0.7143 - val_mean_squared_error: 0.7060
# Epoch 17/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4721 - mean_squared_error: 0.4638 - val_loss: 0.7144 - val_mean_squared_error: 0.7062
# Epoch 18/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4737 - mean_squared_error: 0.4655 - val_loss: 0.7138 - val_mean_squared_error: 0.7057
# Epoch 19/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.4663 - mean_squared_error: 0.4582 - val_loss: 0.7134 - val_mean_squared_error: 0.7054
# Epoch 20/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4628 - mean_squared_error: 0.4548 - val_loss: 0.6871 - val_mean_squared_error: 0.6791
# Epoch 21/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4588 - mean_squared_error: 0.4508 - val_loss: 0.6501 - val_mean_squared_error: 0.6422
# Epoch 22/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.4411 - mean_squared_error: 0.4332 - val_loss: 0.6114 - val_mean_squared_error: 0.6035
# Epoch 23/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.4046 - mean_squared_error: 0.3968 - val_loss: 0.5717 - val_mean_squared_error: 0.5640
# Epoch 24/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.3711 - mean_squared_error: 0.3633 - val_loss: 0.5320 - val_mean_squared_error: 0.5243
# Epoch 25/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.3454 - mean_squared_error: 0.3376 - val_loss: 0.4942 - val_mean_squared_error: 0.4865
# Epoch 26/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.3280 - mean_squared_error: 0.3203 - val_loss: 0.4570 - val_mean_squared_error: 0.4493
# Epoch 27/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.3076 - mean_squared_error: 0.3000 - val_loss: 0.4200 - val_mean_squared_error: 0.4124
# Epoch 28/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.2738 - mean_squared_error: 0.2662 - val_loss: 0.3836 - val_mean_squared_error: 0.3761
# Epoch 29/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.2656 - mean_squared_error: 0.2580 - val_loss: 0.3495 - val_mean_squared_error: 0.3420
# Epoch 30/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.2174 - mean_squared_error: 0.2099 - val_loss: 0.3171 - val_mean_squared_error: 0.3096
# Epoch 31/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.2036 - mean_squared_error: 0.1961 - val_loss: 0.2856 - val_mean_squared_error: 0.2782
# Epoch 32/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.1899 - mean_squared_error: 0.1824 - val_loss: 0.2554 - val_mean_squared_error: 0.2480
# Epoch 33/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.1751 - mean_squared_error: 0.1677 - val_loss: 0.2265 - val_mean_squared_error: 0.2191
# Epoch 34/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.1306 - mean_squared_error: 0.1232 - val_loss: 0.1987 - val_mean_squared_error: 0.1914
# Epoch 35/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.1364 - mean_squared_error: 0.1290 - val_loss: 0.1721 - val_mean_squared_error: 0.1648
# Epoch 36/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.1037 - mean_squared_error: 0.0964 - val_loss: 0.1470 - val_mean_squared_error: 0.1397
# Epoch 37/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0905 - mean_squared_error: 0.0833 - val_loss: 0.1237 - val_mean_squared_error: 0.1164
# Epoch 38/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0965 - mean_squared_error: 0.0892 - val_loss: 0.1020 - val_mean_squared_error: 0.0947
# Epoch 39/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0614 - mean_squared_error: 0.0542 - val_loss: 0.0824 - val_mean_squared_error: 0.0752
# Epoch 40/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0606 - mean_squared_error: 0.0534 - val_loss: 0.0653 - val_mean_squared_error: 0.0582
# Epoch 41/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0477 - mean_squared_error: 0.0405 - val_loss: 0.0508 - val_mean_squared_error: 0.0437
# Epoch 42/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0438 - mean_squared_error: 0.0366 - val_loss: 0.0385 - val_mean_squared_error: 0.0314
# Epoch 43/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0476 - mean_squared_error: 0.0404 - val_loss: 0.0288 - val_mean_squared_error: 0.0217
# Epoch 44/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0385 - mean_squared_error: 0.0314 - val_loss: 0.0212 - val_mean_squared_error: 0.0142
# Epoch 45/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0294 - mean_squared_error: 0.0223 - val_loss: 0.0158 - val_mean_squared_error: 0.0088
# Epoch 46/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0244 - mean_squared_error: 0.0174 - val_loss: 0.0125 - val_mean_squared_error: 0.0054
# Epoch 47/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0352 - mean_squared_error: 0.0282 - val_loss: 0.0108 - val_mean_squared_error: 0.0038
# Epoch 48/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0246 - mean_squared_error: 0.0176 - val_loss: 0.0103 - val_mean_squared_error: 0.0033
# Epoch 49/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0190 - mean_squared_error: 0.0120 - val_loss: 0.0107 - val_mean_squared_error: 0.0037
# Epoch 50/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0246 - mean_squared_error: 0.0176 - val_loss: 0.0116 - val_mean_squared_error: 0.0047
# Epoch 51/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0486 - mean_squared_error: 0.0417 - val_loss: 0.0123 - val_mean_squared_error: 0.0054
# Epoch 52/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0489 - mean_squared_error: 0.0420 - val_loss: 0.0128 - val_mean_squared_error: 0.0059
# Epoch 53/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0601 - mean_squared_error: 0.0532 - val_loss: 0.0126 - val_mean_squared_error: 0.0058
# Epoch 54/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0224 - mean_squared_error: 0.0155 - val_loss: 0.0123 - val_mean_squared_error: 0.0054
# Epoch 55/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0658 - mean_squared_error: 0.0590 - val_loss: 0.0115 - val_mean_squared_error: 0.0047
# Epoch 56/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0361 - mean_squared_error: 0.0293 - val_loss: 0.0108 - val_mean_squared_error: 0.0041
# Epoch 57/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0551 - mean_squared_error: 0.0483 - val_loss: 0.0102 - val_mean_squared_error: 0.0035
# Epoch 58/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0399 - mean_squared_error: 0.0332 - val_loss: 0.0098 - val_mean_squared_error: 0.0031
# Epoch 59/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0372 - mean_squared_error: 0.0305 - val_loss: 0.0097 - val_mean_squared_error: 0.0030
# Epoch 60/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0362 - mean_squared_error: 0.0296 - val_loss: 0.0099 - val_mean_squared_error: 0.0033
# Epoch 61/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0187 - mean_squared_error: 0.0121 - val_loss: 0.0104 - val_mean_squared_error: 0.0038
# Epoch 62/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0255 - mean_squared_error: 0.0189 - val_loss: 0.0112 - val_mean_squared_error: 0.0046
# Epoch 63/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0336 - mean_squared_error: 0.0270 - val_loss: 0.0122 - val_mean_squared_error: 0.0056
# Epoch 64/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0400 - mean_squared_error: 0.0335 - val_loss: 0.0133 - val_mean_squared_error: 0.0068
# Epoch 65/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0225 - mean_squared_error: 0.0160 - val_loss: 0.0145 - val_mean_squared_error: 0.0080
# Epoch 66/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0182 - mean_squared_error: 0.0117 - val_loss: 0.0156 - val_mean_squared_error: 0.0091
# Epoch 67/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0235 - mean_squared_error: 0.0170 - val_loss: 0.0167 - val_mean_squared_error: 0.0102
# Epoch 68/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0208 - mean_squared_error: 0.0144 - val_loss: 0.0178 - val_mean_squared_error: 0.0114
# Epoch 69/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0362 - mean_squared_error: 0.0298 - val_loss: 0.0188 - val_mean_squared_error: 0.0124
# Epoch 70/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0195 - mean_squared_error: 0.0131 - val_loss: 0.0195 - val_mean_squared_error: 0.0132
# Epoch 71/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0227 - mean_squared_error: 0.0163 - val_loss: 0.0201 - val_mean_squared_error: 0.0138
# Epoch 72/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0160 - mean_squared_error: 0.0096 - val_loss: 0.0205 - val_mean_squared_error: 0.0142
# Epoch 73/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0238 - mean_squared_error: 0.0175 - val_loss: 0.0209 - val_mean_squared_error: 0.0146
# Epoch 74/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0312 - mean_squared_error: 0.0249 - val_loss: 0.0207 - val_mean_squared_error: 0.0144
# Epoch 75/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0313 - mean_squared_error: 0.0250 - val_loss: 0.0202 - val_mean_squared_error: 0.0139
# Epoch 76/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0305 - mean_squared_error: 0.0243 - val_loss: 0.0195 - val_mean_squared_error: 0.0133
# Epoch 77/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0178 - mean_squared_error: 0.0115 - val_loss: 0.0188 - val_mean_squared_error: 0.0126
# Epoch 78/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0275 - mean_squared_error: 0.0213 - val_loss: 0.0182 - val_mean_squared_error: 0.0120
# Epoch 79/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0309 - mean_squared_error: 0.0247 - val_loss: 0.0177 - val_mean_squared_error: 0.0115
# Epoch 80/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0211 - mean_squared_error: 0.0149 - val_loss: 0.0170 - val_mean_squared_error: 0.0109
# Epoch 81/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0242 - mean_squared_error: 0.0180 - val_loss: 0.0162 - val_mean_squared_error: 0.0101
# Epoch 82/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0206 - mean_squared_error: 0.0144 - val_loss: 0.0154 - val_mean_squared_error: 0.0093
# Epoch 83/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0253 - mean_squared_error: 0.0192 - val_loss: 0.0145 - val_mean_squared_error: 0.0084
# Epoch 84/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0307 - mean_squared_error: 0.0246 - val_loss: 0.0140 - val_mean_squared_error: 0.0079
# Epoch 85/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0232 - mean_squared_error: 0.0172 - val_loss: 0.0138 - val_mean_squared_error: 0.0078
# Epoch 86/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0217 - mean_squared_error: 0.0157 - val_loss: 0.0136 - val_mean_squared_error: 0.0076
# Epoch 87/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0203 - mean_squared_error: 0.0143 - val_loss: 0.0135 - val_mean_squared_error: 0.0074
# Epoch 88/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0162 - mean_squared_error: 0.0102 - val_loss: 0.0133 - val_mean_squared_error: 0.0073
# Epoch 89/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0222 - mean_squared_error: 0.0162 - val_loss: 0.0133 - val_mean_squared_error: 0.0073
# Epoch 90/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0174 - mean_squared_error: 0.0114 - val_loss: 0.0132 - val_mean_squared_error: 0.0072
# Epoch 91/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0123 - mean_squared_error: 0.0064 - val_loss: 0.0134 - val_mean_squared_error: 0.0074
# Epoch 92/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0330 - mean_squared_error: 0.0271 - val_loss: 0.0137 - val_mean_squared_error: 0.0078
# Epoch 93/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0246 - mean_squared_error: 0.0187 - val_loss: 0.0139 - val_mean_squared_error: 0.0080
# Epoch 94/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0134 - mean_squared_error: 0.0075 - val_loss: 0.0139 - val_mean_squared_error: 0.0080
# Epoch 95/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0180 - mean_squared_error: 0.0121 - val_loss: 0.0141 - val_mean_squared_error: 0.0083
# Epoch 96/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0172 - mean_squared_error: 0.0113 - val_loss: 0.0141 - val_mean_squared_error: 0.0083
# Epoch 97/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0166 - mean_squared_error: 0.0107 - val_loss: 0.0141 - val_mean_squared_error: 0.0083
# Epoch 98/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0280 - mean_squared_error: 0.0221 - val_loss: 0.0142 - val_mean_squared_error: 0.0084
# Epoch 99/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0284 - mean_squared_error: 0.0226 - val_loss: 0.0142 - val_mean_squared_error: 0.0084
# Epoch 100/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0157 - mean_squared_error: 0.0099 - val_loss: 0.0138 - val_mean_squared_error: 0.0080
# Epoch 101/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0082 - mean_squared_error: 0.0025 - val_loss: 0.0134 - val_mean_squared_error: 0.0076
# Epoch 102/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0182 - mean_squared_error: 0.0124 - val_loss: 0.0131 - val_mean_squared_error: 0.0073
# Epoch 103/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0167 - mean_squared_error: 0.0110 - val_loss: 0.0130 - val_mean_squared_error: 0.0072
# Epoch 104/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0277 - mean_squared_error: 0.0220 - val_loss: 0.0132 - val_mean_squared_error: 0.0074
# Epoch 105/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0178 - mean_squared_error: 0.0121 - val_loss: 0.0129 - val_mean_squared_error: 0.0072
# Epoch 106/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0265 - mean_squared_error: 0.0208 - val_loss: 0.0129 - val_mean_squared_error: 0.0072
# Epoch 107/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0174 - mean_squared_error: 0.0117 - val_loss: 0.0131 - val_mean_squared_error: 0.0074
# Epoch 108/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0156 - mean_squared_error: 0.0099 - val_loss: 0.0134 - val_mean_squared_error: 0.0077
# Epoch 109/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0104 - mean_squared_error: 0.0047 - val_loss: 0.0135 - val_mean_squared_error: 0.0078
# Epoch 110/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0089 - mean_squared_error: 0.0032 - val_loss: 0.0134 - val_mean_squared_error: 0.0078
# Epoch 111/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0108 - mean_squared_error: 0.0052 - val_loss: 0.0132 - val_mean_squared_error: 0.0075
# Epoch 112/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0143 - mean_squared_error: 0.0087 - val_loss: 0.0132 - val_mean_squared_error: 0.0076
# Epoch 113/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0134 - mean_squared_error: 0.0078 - val_loss: 0.0132 - val_mean_squared_error: 0.0076
# Epoch 114/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0197 - mean_squared_error: 0.0141 - val_loss: 0.0133 - val_mean_squared_error: 0.0077
# Epoch 115/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0155 - mean_squared_error: 0.0099 - val_loss: 0.0130 - val_mean_squared_error: 0.0074
# Epoch 116/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0136 - mean_squared_error: 0.0080 - val_loss: 0.0130 - val_mean_squared_error: 0.0074
# Epoch 117/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0184 - mean_squared_error: 0.0128 - val_loss: 0.0124 - val_mean_squared_error: 0.0069
# Epoch 118/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0201 - mean_squared_error: 0.0145 - val_loss: 0.0122 - val_mean_squared_error: 0.0067
# Epoch 119/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0174 - mean_squared_error: 0.0119 - val_loss: 0.0120 - val_mean_squared_error: 0.0065
# Epoch 120/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0124 - mean_squared_error: 0.0068 - val_loss: 0.0118 - val_mean_squared_error: 0.0063
# Epoch 121/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0139 - mean_squared_error: 0.0083 - val_loss: 0.0114 - val_mean_squared_error: 0.0059
# Epoch 122/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0282 - mean_squared_error: 0.0227 - val_loss: 0.0111 - val_mean_squared_error: 0.0056
# Epoch 123/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0146 - mean_squared_error: 0.0091 - val_loss: 0.0113 - val_mean_squared_error: 0.0058
# Epoch 124/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0098 - mean_squared_error: 0.0044 - val_loss: 0.0117 - val_mean_squared_error: 0.0063
# Epoch 125/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0129 - mean_squared_error: 0.0075 - val_loss: 0.0123 - val_mean_squared_error: 0.0069
# Epoch 126/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0071 - mean_squared_error: 0.0016 - val_loss: 0.0129 - val_mean_squared_error: 0.0075
# Epoch 127/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0140 - mean_squared_error: 0.0086 - val_loss: 0.0138 - val_mean_squared_error: 0.0083
# Epoch 128/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0108 - mean_squared_error: 0.0054 - val_loss: 0.0150 - val_mean_squared_error: 0.0096
# Epoch 129/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0086 - mean_squared_error: 0.0032 - val_loss: 0.0159 - val_mean_squared_error: 0.0104
# Epoch 130/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0122 - mean_squared_error: 0.0067 - val_loss: 0.0166 - val_mean_squared_error: 0.0112
# Epoch 131/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0090 - mean_squared_error: 0.0036 - val_loss: 0.0171 - val_mean_squared_error: 0.0117
# Epoch 132/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0123 - mean_squared_error: 0.0069 - val_loss: 0.0177 - val_mean_squared_error: 0.0123
# Epoch 133/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0091 - mean_squared_error: 0.0038 - val_loss: 0.0178 - val_mean_squared_error: 0.0124
# Epoch 134/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0093 - mean_squared_error: 0.0040 - val_loss: 0.0177 - val_mean_squared_error: 0.0123
# Epoch 135/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0114 - mean_squared_error: 0.0061 - val_loss: 0.0169 - val_mean_squared_error: 0.0116
# Epoch 136/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0188 - mean_squared_error: 0.0134 - val_loss: 0.0156 - val_mean_squared_error: 0.0103
# Epoch 137/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0086 - mean_squared_error: 0.0033 - val_loss: 0.0142 - val_mean_squared_error: 0.0089
# Epoch 138/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0141 - mean_squared_error: 0.0088 - val_loss: 0.0129 - val_mean_squared_error: 0.0076
# Epoch 139/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0128 - mean_squared_error: 0.0075 - val_loss: 0.0119 - val_mean_squared_error: 0.0066
# Epoch 140/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0136 - mean_squared_error: 0.0082 - val_loss: 0.0114 - val_mean_squared_error: 0.0061
# Epoch 141/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0148 - mean_squared_error: 0.0094 - val_loss: 0.0115 - val_mean_squared_error: 0.0062
# Epoch 142/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0097 - mean_squared_error: 0.0044 - val_loss: 0.0114 - val_mean_squared_error: 0.0061
# Epoch 143/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0109 - mean_squared_error: 0.0056 - val_loss: 0.0115 - val_mean_squared_error: 0.0062
# Epoch 144/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0221 - mean_squared_error: 0.0168 - val_loss: 0.0117 - val_mean_squared_error: 0.0065
# Epoch 145/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0090 - mean_squared_error: 0.0037 - val_loss: 0.0119 - val_mean_squared_error: 0.0066
# Epoch 146/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0105 - mean_squared_error: 0.0053 - val_loss: 0.0122 - val_mean_squared_error: 0.0069
# Epoch 147/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0105 - mean_squared_error: 0.0052 - val_loss: 0.0125 - val_mean_squared_error: 0.0072
# Epoch 148/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0168 - mean_squared_error: 0.0115 - val_loss: 0.0134 - val_mean_squared_error: 0.0082
# Epoch 149/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0082 - mean_squared_error: 0.0030 - val_loss: 0.0148 - val_mean_squared_error: 0.0095
# Epoch 150/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0091 - mean_squared_error: 0.0039 - val_loss: 0.0156 - val_mean_squared_error: 0.0104
# Epoch 151/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0068 - mean_squared_error: 0.0016 - val_loss: 0.0163 - val_mean_squared_error: 0.0111
# Epoch 152/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0086 - mean_squared_error: 0.0034 - val_loss: 0.0170 - val_mean_squared_error: 0.0118
# Epoch 153/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0109 - mean_squared_error: 0.0057 - val_loss: 0.0169 - val_mean_squared_error: 0.0117
# Epoch 154/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0162 - mean_squared_error: 0.0110 - val_loss: 0.0158 - val_mean_squared_error: 0.0106
# Epoch 155/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0099 - mean_squared_error: 0.0047 - val_loss: 0.0148 - val_mean_squared_error: 0.0096
# Epoch 156/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0197 - mean_squared_error: 0.0146 - val_loss: 0.0140 - val_mean_squared_error: 0.0088
# Epoch 157/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0174 - mean_squared_error: 0.0122 - val_loss: 0.0137 - val_mean_squared_error: 0.0085
# Epoch 158/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0091 - mean_squared_error: 0.0039 - val_loss: 0.0132 - val_mean_squared_error: 0.0080
# Epoch 159/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0092 - mean_squared_error: 0.0040 - val_loss: 0.0130 - val_mean_squared_error: 0.0079
# Epoch 160/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0123 - mean_squared_error: 0.0072 - val_loss: 0.0129 - val_mean_squared_error: 0.0077
# Epoch 161/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0234 - mean_squared_error: 0.0182 - val_loss: 0.0133 - val_mean_squared_error: 0.0082
# Epoch 162/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0130 - mean_squared_error: 0.0079 - val_loss: 0.0139 - val_mean_squared_error: 0.0088
# Epoch 163/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0087 - mean_squared_error: 0.0036 - val_loss: 0.0144 - val_mean_squared_error: 0.0093
# Epoch 164/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0138 - mean_squared_error: 0.0086 - val_loss: 0.0149 - val_mean_squared_error: 0.0098
# Epoch 165/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0157 - mean_squared_error: 0.0106 - val_loss: 0.0161 - val_mean_squared_error: 0.0110
# Epoch 166/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0109 - mean_squared_error: 0.0058 - val_loss: 0.0172 - val_mean_squared_error: 0.0121
# Epoch 167/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0078 - mean_squared_error: 0.0027 - val_loss: 0.0180 - val_mean_squared_error: 0.0130
# Epoch 168/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0086 - mean_squared_error: 0.0036 - val_loss: 0.0190 - val_mean_squared_error: 0.0139
# Epoch 169/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0102 - mean_squared_error: 0.0051 - val_loss: 0.0201 - val_mean_squared_error: 0.0150
# Epoch 170/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0105 - mean_squared_error: 0.0054 - val_loss: 0.0205 - val_mean_squared_error: 0.0155
# Epoch 171/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0105 - mean_squared_error: 0.0054 - val_loss: 0.0208 - val_mean_squared_error: 0.0158
# Epoch 172/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0110 - mean_squared_error: 0.0059 - val_loss: 0.0209 - val_mean_squared_error: 0.0159
# Epoch 173/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0101 - mean_squared_error: 0.0051 - val_loss: 0.0201 - val_mean_squared_error: 0.0151
# Epoch 174/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0069 - mean_squared_error: 0.0019 - val_loss: 0.0196 - val_mean_squared_error: 0.0146
# Epoch 175/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0072 - mean_squared_error: 0.0022 - val_loss: 0.0189 - val_mean_squared_error: 0.0138
# Epoch 176/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0094 - mean_squared_error: 0.0044 - val_loss: 0.0183 - val_mean_squared_error: 0.0133
# Epoch 177/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0111 - mean_squared_error: 0.0061 - val_loss: 0.0169 - val_mean_squared_error: 0.0119
# Epoch 178/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0114 - mean_squared_error: 0.0064 - val_loss: 0.0155 - val_mean_squared_error: 0.0105
# Epoch 179/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0091 - mean_squared_error: 0.0041 - val_loss: 0.0141 - val_mean_squared_error: 0.0091
# Epoch 180/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0116 - mean_squared_error: 0.0066 - val_loss: 0.0125 - val_mean_squared_error: 0.0075
# Epoch 181/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0106 - mean_squared_error: 0.0056 - val_loss: 0.0113 - val_mean_squared_error: 0.0063
# Epoch 182/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0084 - mean_squared_error: 0.0035 - val_loss: 0.0107 - val_mean_squared_error: 0.0057
# Epoch 183/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0086 - mean_squared_error: 0.0036 - val_loss: 0.0103 - val_mean_squared_error: 0.0053
# Epoch 184/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0143 - mean_squared_error: 0.0093 - val_loss: 0.0104 - val_mean_squared_error: 0.0055
# Epoch 185/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0149 - mean_squared_error: 0.0100 - val_loss: 0.0112 - val_mean_squared_error: 0.0062
# Epoch 186/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0114 - mean_squared_error: 0.0064 - val_loss: 0.0116 - val_mean_squared_error: 0.0067
# Epoch 187/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0114 - mean_squared_error: 0.0064 - val_loss: 0.0121 - val_mean_squared_error: 0.0072
# Epoch 188/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0304 - mean_squared_error: 0.0255 - val_loss: 0.0126 - val_mean_squared_error: 0.0077
# Epoch 189/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0072 - mean_squared_error: 0.0023 - val_loss: 0.0134 - val_mean_squared_error: 0.0085
# Epoch 190/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0100 - mean_squared_error: 0.0051 - val_loss: 0.0146 - val_mean_squared_error: 0.0097
# Epoch 191/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0116 - mean_squared_error: 0.0067 - val_loss: 0.0155 - val_mean_squared_error: 0.0106
# Epoch 192/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0106 - mean_squared_error: 0.0057 - val_loss: 0.0160 - val_mean_squared_error: 0.0111
# Epoch 193/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0086 - mean_squared_error: 0.0037 - val_loss: 0.0162 - val_mean_squared_error: 0.0113
# Epoch 194/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0157 - mean_squared_error: 0.0108 - val_loss: 0.0164 - val_mean_squared_error: 0.0115
# Epoch 195/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0089 - mean_squared_error: 0.0040 - val_loss: 0.0168 - val_mean_squared_error: 0.0119
# Epoch 196/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0110 - mean_squared_error: 0.0061 - val_loss: 0.0174 - val_mean_squared_error: 0.0126
# Epoch 197/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0096 - mean_squared_error: 0.0048 - val_loss: 0.0181 - val_mean_squared_error: 0.0132
# Epoch 198/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0062 - mean_squared_error: 0.0013 - val_loss: 0.0186 - val_mean_squared_error: 0.0138
# Epoch 199/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0188 - mean_squared_error: 0.0139 - val_loss: 0.0179 - val_mean_squared_error: 0.0130
# Epoch 200/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0092 - mean_squared_error: 0.0043 - val_loss: 0.0169 - val_mean_squared_error: 0.0121
# Epoch 201/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0102 - mean_squared_error: 0.0054 - val_loss: 0.0156 - val_mean_squared_error: 0.0108
# Epoch 202/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0126 - mean_squared_error: 0.0077 - val_loss: 0.0148 - val_mean_squared_error: 0.0100
# Epoch 203/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0072 - mean_squared_error: 0.0024 - val_loss: 0.0142 - val_mean_squared_error: 0.0093
# Epoch 204/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0082 - mean_squared_error: 0.0034 - val_loss: 0.0133 - val_mean_squared_error: 0.0084
# Epoch 205/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0108 - mean_squared_error: 0.0060 - val_loss: 0.0124 - val_mean_squared_error: 0.0076
# Epoch 206/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0134 - mean_squared_error: 0.0086 - val_loss: 0.0118 - val_mean_squared_error: 0.0070
# Epoch 207/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0122 - mean_squared_error: 0.0074 - val_loss: 0.0109 - val_mean_squared_error: 0.0061
# Epoch 208/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0108 - mean_squared_error: 0.0060 - val_loss: 0.0103 - val_mean_squared_error: 0.0056
# Epoch 209/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0074 - mean_squared_error: 0.0026 - val_loss: 0.0100 - val_mean_squared_error: 0.0053
# Epoch 210/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0149 - mean_squared_error: 0.0102 - val_loss: 0.0098 - val_mean_squared_error: 0.0051
# Epoch 211/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0153 - mean_squared_error: 0.0105 - val_loss: 0.0101 - val_mean_squared_error: 0.0053
# Epoch 212/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0184 - mean_squared_error: 0.0137 - val_loss: 0.0108 - val_mean_squared_error: 0.0061
# Epoch 213/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0120 - mean_squared_error: 0.0072 - val_loss: 0.0124 - val_mean_squared_error: 0.0076
# Epoch 214/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0080 - mean_squared_error: 0.0032 - val_loss: 0.0142 - val_mean_squared_error: 0.0094
# Epoch 215/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0095 - mean_squared_error: 0.0048 - val_loss: 0.0162 - val_mean_squared_error: 0.0115
# Epoch 216/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0127 - mean_squared_error: 0.0079 - val_loss: 0.0180 - val_mean_squared_error: 0.0133
# Epoch 217/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0098 - mean_squared_error: 0.0051 - val_loss: 0.0193 - val_mean_squared_error: 0.0145
# Epoch 218/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0083 - mean_squared_error: 0.0035 - val_loss: 0.0197 - val_mean_squared_error: 0.0150
# Epoch 219/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0085 - mean_squared_error: 0.0037 - val_loss: 0.0202 - val_mean_squared_error: 0.0155
# Epoch 220/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0121 - mean_squared_error: 0.0074 - val_loss: 0.0199 - val_mean_squared_error: 0.0152
# Epoch 221/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0124 - mean_squared_error: 0.0077 - val_loss: 0.0189 - val_mean_squared_error: 0.0142
# Epoch 222/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0086 - mean_squared_error: 0.0039 - val_loss: 0.0173 - val_mean_squared_error: 0.0126
# Epoch 223/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0090 - mean_squared_error: 0.0043 - val_loss: 0.0160 - val_mean_squared_error: 0.0113
# Epoch 224/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0079 - mean_squared_error: 0.0032 - val_loss: 0.0151 - val_mean_squared_error: 0.0104
# Epoch 225/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0106 - mean_squared_error: 0.0059 - val_loss: 0.0139 - val_mean_squared_error: 0.0093
# Epoch 226/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0079 - mean_squared_error: 0.0032 - val_loss: 0.0129 - val_mean_squared_error: 0.0083
# Epoch 227/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0079 - mean_squared_error: 0.0033 - val_loss: 0.0124 - val_mean_squared_error: 0.0077
# Epoch 228/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0105 - mean_squared_error: 0.0058 - val_loss: 0.0121 - val_mean_squared_error: 0.0074
# Epoch 229/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0153 - mean_squared_error: 0.0106 - val_loss: 0.0120 - val_mean_squared_error: 0.0073
# Epoch 230/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0073 - mean_squared_error: 0.0026 - val_loss: 0.0121 - val_mean_squared_error: 0.0074
# Epoch 231/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0132 - mean_squared_error: 0.0086 - val_loss: 0.0126 - val_mean_squared_error: 0.0080
# Epoch 232/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0092 - mean_squared_error: 0.0046 - val_loss: 0.0128 - val_mean_squared_error: 0.0082
# Epoch 233/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0071 - mean_squared_error: 0.0025 - val_loss: 0.0132 - val_mean_squared_error: 0.0085
# Epoch 234/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0128 - mean_squared_error: 0.0081 - val_loss: 0.0130 - val_mean_squared_error: 0.0084
# Epoch 235/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0107 - mean_squared_error: 0.0061 - val_loss: 0.0130 - val_mean_squared_error: 0.0084
# Epoch 236/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0118 - mean_squared_error: 0.0072 - val_loss: 0.0136 - val_mean_squared_error: 0.0090
# Epoch 237/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0087 - mean_squared_error: 0.0041 - val_loss: 0.0148 - val_mean_squared_error: 0.0102
# Epoch 238/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0106 - mean_squared_error: 0.0060 - val_loss: 0.0155 - val_mean_squared_error: 0.0109
# Epoch 239/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0110 - mean_squared_error: 0.0064 - val_loss: 0.0168 - val_mean_squared_error: 0.0122
# Epoch 240/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0123 - mean_squared_error: 0.0077 - val_loss: 0.0183 - val_mean_squared_error: 0.0137
# Epoch 241/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0165 - mean_squared_error: 0.0120 - val_loss: 0.0193 - val_mean_squared_error: 0.0148
# Epoch 242/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0131 - mean_squared_error: 0.0085 - val_loss: 0.0195 - val_mean_squared_error: 0.0149
# Epoch 243/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0104 - mean_squared_error: 0.0059 - val_loss: 0.0190 - val_mean_squared_error: 0.0144
# Epoch 244/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0107 - mean_squared_error: 0.0062 - val_loss: 0.0188 - val_mean_squared_error: 0.0142
# Epoch 245/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0057 - mean_squared_error: 0.0012 - val_loss: 0.0182 - val_mean_squared_error: 0.0137
# Epoch 246/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0096 - mean_squared_error: 0.0050 - val_loss: 0.0176 - val_mean_squared_error: 0.0130
# Epoch 247/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0098 - mean_squared_error: 0.0052 - val_loss: 0.0164 - val_mean_squared_error: 0.0118
# Epoch 248/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0111 - mean_squared_error: 0.0065 - val_loss: 0.0152 - val_mean_squared_error: 0.0107
# Epoch 249/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0124 - mean_squared_error: 0.0078 - val_loss: 0.0142 - val_mean_squared_error: 0.0096
# Epoch 250/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0106 - mean_squared_error: 0.0060 - val_loss: 0.0128 - val_mean_squared_error: 0.0082
# Epoch 251/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0085 - mean_squared_error: 0.0039 - val_loss: 0.0121 - val_mean_squared_error: 0.0075
# Epoch 252/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0094 - mean_squared_error: 0.0049 - val_loss: 0.0115 - val_mean_squared_error: 0.0070
# Epoch 253/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0117 - mean_squared_error: 0.0072 - val_loss: 0.0110 - val_mean_squared_error: 0.0064
# Epoch 254/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0105 - mean_squared_error: 0.0060 - val_loss: 0.0103 - val_mean_squared_error: 0.0058
# Epoch 255/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0089 - mean_squared_error: 0.0044 - val_loss: 0.0099 - val_mean_squared_error: 0.0054
# Epoch 256/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0075 - mean_squared_error: 0.0030 - val_loss: 0.0095 - val_mean_squared_error: 0.0049
# Epoch 257/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0080 - mean_squared_error: 0.0034 - val_loss: 0.0097 - val_mean_squared_error: 0.0052
# Epoch 258/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0111 - mean_squared_error: 0.0065 - val_loss: 0.0099 - val_mean_squared_error: 0.0054
# Epoch 259/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0067 - mean_squared_error: 0.0022 - val_loss: 0.0105 - val_mean_squared_error: 0.0060
# Epoch 260/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0053 - mean_squared_error: 8.1481e-04 - val_loss: 0.0112 - val_mean_squared_error: 0.0067
# Epoch 261/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0217 - mean_squared_error: 0.0172 - val_loss: 0.0109 - val_mean_squared_error: 0.0064
# Epoch 262/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0084 - mean_squared_error: 0.0039 - val_loss: 0.0104 - val_mean_squared_error: 0.0059
# Epoch 263/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0100 - mean_squared_error: 0.0055 - val_loss: 0.0104 - val_mean_squared_error: 0.0060
# Epoch 264/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0166 - mean_squared_error: 0.0121 - val_loss: 0.0104 - val_mean_squared_error: 0.0059
# Epoch 265/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0132 - mean_squared_error: 0.0087 - val_loss: 0.0111 - val_mean_squared_error: 0.0067
# Epoch 266/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0084 - mean_squared_error: 0.0039 - val_loss: 0.0121 - val_mean_squared_error: 0.0076
# Epoch 267/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0071 - mean_squared_error: 0.0026 - val_loss: 0.0133 - val_mean_squared_error: 0.0088
# Epoch 268/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0139 - mean_squared_error: 0.0094 - val_loss: 0.0138 - val_mean_squared_error: 0.0094
# Epoch 269/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0048 - mean_squared_error: 3.8598e-04 - val_loss: 0.0143 - val_mean_squared_error: 0.0099
# Epoch 270/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0074 - mean_squared_error: 0.0029 - val_loss: 0.0145 - val_mean_squared_error: 0.0101
# Epoch 271/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0126 - mean_squared_error: 0.0081 - val_loss: 0.0149 - val_mean_squared_error: 0.0105
# Epoch 272/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0159 - mean_squared_error: 0.0114 - val_loss: 0.0141 - val_mean_squared_error: 0.0097
# Epoch 273/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0112 - mean_squared_error: 0.0068 - val_loss: 0.0132 - val_mean_squared_error: 0.0088
# Epoch 274/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0108 - mean_squared_error: 0.0063 - val_loss: 0.0125 - val_mean_squared_error: 0.0081
# Epoch 275/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0087 - mean_squared_error: 0.0042 - val_loss: 0.0120 - val_mean_squared_error: 0.0075
# Epoch 276/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0068 - mean_squared_error: 0.0024 - val_loss: 0.0118 - val_mean_squared_error: 0.0074
# Epoch 277/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0102 - mean_squared_error: 0.0058 - val_loss: 0.0121 - val_mean_squared_error: 0.0077
# Epoch 278/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0052 - mean_squared_error: 7.8927e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0077
# Epoch 279/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0069 - mean_squared_error: 0.0025 - val_loss: 0.0125 - val_mean_squared_error: 0.0081
# Epoch 280/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0066 - mean_squared_error: 0.0022 - val_loss: 0.0130 - val_mean_squared_error: 0.0086
# Epoch 281/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0092 - mean_squared_error: 0.0048 - val_loss: 0.0135 - val_mean_squared_error: 0.0091
# Epoch 282/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0130 - mean_squared_error: 0.0086 - val_loss: 0.0137 - val_mean_squared_error: 0.0093
# Epoch 283/500
# 6/6 [==============================] - 0s 498us/step - loss: 0.0123 - mean_squared_error: 0.0079 - val_loss: 0.0132 - val_mean_squared_error: 0.0088
# Epoch 284/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0125 - mean_squared_error: 0.0081 - val_loss: 0.0125 - val_mean_squared_error: 0.0081
# Epoch 285/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0135 - mean_squared_error: 0.0091 - val_loss: 0.0120 - val_mean_squared_error: 0.0076
# Epoch 286/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0107 - mean_squared_error: 0.0064 - val_loss: 0.0111 - val_mean_squared_error: 0.0067
# Epoch 287/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0161 - mean_squared_error: 0.0118 - val_loss: 0.0114 - val_mean_squared_error: 0.0071
# Epoch 288/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0076 - mean_squared_error: 0.0033 - val_loss: 0.0123 - val_mean_squared_error: 0.0079
# Epoch 289/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0096 - mean_squared_error: 0.0053 - val_loss: 0.0127 - val_mean_squared_error: 0.0083
# Epoch 290/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0083 - mean_squared_error: 0.0040 - val_loss: 0.0124 - val_mean_squared_error: 0.0081
# Epoch 291/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0076 - mean_squared_error: 0.0033 - val_loss: 0.0121 - val_mean_squared_error: 0.0077
# Epoch 292/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0061 - mean_squared_error: 0.0018 - val_loss: 0.0118 - val_mean_squared_error: 0.0075
# Epoch 293/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0102 - mean_squared_error: 0.0059 - val_loss: 0.0124 - val_mean_squared_error: 0.0081
# Epoch 294/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0119 - mean_squared_error: 0.0075 - val_loss: 0.0132 - val_mean_squared_error: 0.0089
# ...
# 6/6 [==============================] - 0s 332us/step - loss: 0.0081 - mean_squared_error: 0.0042 - val_loss: 0.0118 - val_mean_squared_error: 0.0079
# Epoch 405/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0101 - mean_squared_error: 0.0062 - val_loss: 0.0118 - val_mean_squared_error: 0.0079
# Epoch 406/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0110 - mean_squared_error: 0.0072 - val_loss: 0.0113 - val_mean_squared_error: 0.0074
# Epoch 407/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0099 - mean_squared_error: 0.0060 - val_loss: 0.0104 - val_mean_squared_error: 0.0066
# Epoch 408/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0070 - mean_squared_error: 0.0031 - val_loss: 0.0099 - val_mean_squared_error: 0.0061
# Epoch 409/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0106 - mean_squared_error: 0.0067 - val_loss: 0.0093 - val_mean_squared_error: 0.0054
# Epoch 410/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0046 - mean_squared_error: 7.1558e-04 - val_loss: 0.0087 - val_mean_squared_error: 0.0049
# Epoch 411/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0112 - mean_squared_error: 0.0073 - val_loss: 0.0083 - val_mean_squared_error: 0.0044
# Epoch 412/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0097 - mean_squared_error: 0.0059 - val_loss: 0.0082 - val_mean_squared_error: 0.0043
# Epoch 413/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0055 - mean_squared_error: 0.0017 - val_loss: 0.0081 - val_mean_squared_error: 0.0042
# Epoch 414/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0076 - mean_squared_error: 0.0038 - val_loss: 0.0080 - val_mean_squared_error: 0.0041
# Epoch 415/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0069 - mean_squared_error: 0.0030 - val_loss: 0.0081 - val_mean_squared_error: 0.0043
# Epoch 416/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0055 - mean_squared_error: 0.0016 - val_loss: 0.0083 - val_mean_squared_error: 0.0044
# Epoch 417/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0109 - mean_squared_error: 0.0071 - val_loss: 0.0083 - val_mean_squared_error: 0.0045
# Epoch 418/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0111 - mean_squared_error: 0.0073 - val_loss: 0.0085 - val_mean_squared_error: 0.0046
# Epoch 419/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0066 - mean_squared_error: 0.0028 - val_loss: 0.0085 - val_mean_squared_error: 0.0046
# Epoch 420/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0047 - mean_squared_error: 8.1344e-04 - val_loss: 0.0085 - val_mean_squared_error: 0.0047
# Epoch 421/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0083 - mean_squared_error: 0.0045 - val_loss: 0.0087 - val_mean_squared_error: 0.0048
# Epoch 422/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0052 - mean_squared_error: 0.0014 - val_loss: 0.0090 - val_mean_squared_error: 0.0051
# Epoch 423/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0105 - mean_squared_error: 0.0067 - val_loss: 0.0092 - val_mean_squared_error: 0.0054
# Epoch 424/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0229 - mean_squared_error: 0.0191 - val_loss: 0.0095 - val_mean_squared_error: 0.0057
# Epoch 425/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0062 - mean_squared_error: 0.0024 - val_loss: 0.0097 - val_mean_squared_error: 0.0059
# Epoch 426/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0081 - mean_squared_error: 0.0043 - val_loss: 0.0096 - val_mean_squared_error: 0.0058
# Epoch 427/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0056 - mean_squared_error: 0.0017 - val_loss: 0.0094 - val_mean_squared_error: 0.0056
# Epoch 428/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0060 - mean_squared_error: 0.0021 - val_loss: 0.0090 - val_mean_squared_error: 0.0052
# Epoch 429/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0055 - mean_squared_error: 0.0017 - val_loss: 0.0088 - val_mean_squared_error: 0.0050
# Epoch 430/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0120 - mean_squared_error: 0.0082 - val_loss: 0.0094 - val_mean_squared_error: 0.0055
# Epoch 431/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0067 - mean_squared_error: 0.0029 - val_loss: 0.0101 - val_mean_squared_error: 0.0063
# Epoch 432/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0079 - mean_squared_error: 0.0041 - val_loss: 0.0112 - val_mean_squared_error: 0.0074
# Epoch 433/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0084 - mean_squared_error: 0.0046 - val_loss: 0.0125 - val_mean_squared_error: 0.0087
# Epoch 434/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0054 - mean_squared_error: 0.0016 - val_loss: 0.0137 - val_mean_squared_error: 0.0099
# Epoch 435/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0057 - mean_squared_error: 0.0019 - val_loss: 0.0146 - val_mean_squared_error: 0.0108
# Epoch 436/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0070 - mean_squared_error: 0.0032 - val_loss: 0.0153 - val_mean_squared_error: 0.0115
# Epoch 437/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0151 - mean_squared_error: 0.0113 - val_loss: 0.0144 - val_mean_squared_error: 0.0106
# Epoch 438/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0098 - mean_squared_error: 0.0060 - val_loss: 0.0133 - val_mean_squared_error: 0.0095
# Epoch 439/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0069 - mean_squared_error: 0.0031 - val_loss: 0.0120 - val_mean_squared_error: 0.0082
# Epoch 440/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0054 - mean_squared_error: 0.0016 - val_loss: 0.0110 - val_mean_squared_error: 0.0072
# Epoch 441/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0090 - mean_squared_error: 0.0052 - val_loss: 0.0101 - val_mean_squared_error: 0.0063
# Epoch 442/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0080 - mean_squared_error: 0.0042 - val_loss: 0.0091 - val_mean_squared_error: 0.0053
# Epoch 443/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0058 - mean_squared_error: 0.0021 - val_loss: 0.0083 - val_mean_squared_error: 0.0045
# Epoch 444/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0072 - mean_squared_error: 0.0035 - val_loss: 0.0080 - val_mean_squared_error: 0.0042
# Epoch 445/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0051 - mean_squared_error: 0.0013 - val_loss: 0.0079 - val_mean_squared_error: 0.0042
# Epoch 446/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0096 - mean_squared_error: 0.0058 - val_loss: 0.0083 - val_mean_squared_error: 0.0045
# Epoch 447/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0053 - mean_squared_error: 0.0015 - val_loss: 0.0084 - val_mean_squared_error: 0.0046
# Epoch 448/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0074 - mean_squared_error: 0.0037 - val_loss: 0.0083 - val_mean_squared_error: 0.0045
# Epoch 449/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0083 - mean_squared_error: 0.0045 - val_loss: 0.0077 - val_mean_squared_error: 0.0040
# Epoch 450/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0063 - mean_squared_error: 0.0026 - val_loss: 0.0076 - val_mean_squared_error: 0.0039
# Epoch 451/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0068 - mean_squared_error: 0.0031 - val_loss: 0.0073 - val_mean_squared_error: 0.0036
# Epoch 452/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0060 - mean_squared_error: 0.0022 - val_loss: 0.0072 - val_mean_squared_error: 0.0035
# Epoch 453/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0057 - mean_squared_error: 0.0020 - val_loss: 0.0070 - val_mean_squared_error: 0.0033
# Epoch 454/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0056 - mean_squared_error: 0.0019 - val_loss: 0.0070 - val_mean_squared_error: 0.0032
# Epoch 455/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0070 - mean_squared_error: 0.0032 - val_loss: 0.0073 - val_mean_squared_error: 0.0035
# Epoch 456/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0120 - mean_squared_error: 0.0082 - val_loss: 0.0080 - val_mean_squared_error: 0.0043
# Epoch 457/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0058 - mean_squared_error: 0.0020 - val_loss: 0.0088 - val_mean_squared_error: 0.0051
# Epoch 458/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0073 - mean_squared_error: 0.0035 - val_loss: 0.0095 - val_mean_squared_error: 0.0057
# Epoch 459/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0071 - mean_squared_error: 0.0034 - val_loss: 0.0105 - val_mean_squared_error: 0.0067
# Epoch 460/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0078 - mean_squared_error: 0.0040 - val_loss: 0.0115 - val_mean_squared_error: 0.0078
# Epoch 461/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0074 - mean_squared_error: 0.0037 - val_loss: 0.0125 - val_mean_squared_error: 0.0088
# Epoch 462/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0083 - mean_squared_error: 0.0046 - val_loss: 0.0135 - val_mean_squared_error: 0.0097
# Epoch 463/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0052 - mean_squared_error: 0.0015 - val_loss: 0.0141 - val_mean_squared_error: 0.0104
# Epoch 464/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0087 - mean_squared_error: 0.0050 - val_loss: 0.0141 - val_mean_squared_error: 0.0104
# Epoch 465/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0062 - mean_squared_error: 0.0025 - val_loss: 0.0138 - val_mean_squared_error: 0.0101
# Epoch 466/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0059 - mean_squared_error: 0.0022 - val_loss: 0.0138 - val_mean_squared_error: 0.0101
# Epoch 467/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0087 - mean_squared_error: 0.0050 - val_loss: 0.0141 - val_mean_squared_error: 0.0104
# Epoch 468/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0069 - mean_squared_error: 0.0032 - val_loss: 0.0135 - val_mean_squared_error: 0.0098
# Epoch 469/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0088 - mean_squared_error: 0.0051 - val_loss: 0.0124 - val_mean_squared_error: 0.0087
# Epoch 470/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0055 - mean_squared_error: 0.0018 - val_loss: 0.0112 - val_mean_squared_error: 0.0075
# Epoch 471/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0065 - mean_squared_error: 0.0029 - val_loss: 0.0101 - val_mean_squared_error: 0.0064
# Epoch 472/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0123 - mean_squared_error: 0.0086 - val_loss: 0.0095 - val_mean_squared_error: 0.0058
# Epoch 473/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0063 - mean_squared_error: 0.0027 - val_loss: 0.0088 - val_mean_squared_error: 0.0051
# Epoch 474/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0083 - mean_squared_error: 0.0046 - val_loss: 0.0077 - val_mean_squared_error: 0.0041
# Epoch 475/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0039 - mean_squared_error: 1.8531e-04 - val_loss: 0.0069 - val_mean_squared_error: 0.0033
# Epoch 476/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0059 - mean_squared_error: 0.0023 - val_loss: 0.0067 - val_mean_squared_error: 0.0030
# Epoch 477/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0099 - mean_squared_error: 0.0063 - val_loss: 0.0068 - val_mean_squared_error: 0.0031
# Epoch 478/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0068 - mean_squared_error: 0.0031 - val_loss: 0.0072 - val_mean_squared_error: 0.0035
# Epoch 479/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0081 - mean_squared_error: 0.0044 - val_loss: 0.0078 - val_mean_squared_error: 0.0042
# Epoch 480/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0052 - mean_squared_error: 0.0015 - val_loss: 0.0086 - val_mean_squared_error: 0.0049
# Epoch 481/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0046 - mean_squared_error: 9.4199e-04 - val_loss: 0.0097 - val_mean_squared_error: 0.0060
# Epoch 482/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0050 - mean_squared_error: 0.0013 - val_loss: 0.0108 - val_mean_squared_error: 0.0071
# Epoch 483/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0089 - mean_squared_error: 0.0052 - val_loss: 0.0121 - val_mean_squared_error: 0.0084
# Epoch 484/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0052 - mean_squared_error: 0.0016 - val_loss: 0.0133 - val_mean_squared_error: 0.0096
# Epoch 485/500
# 6/6 [==============================] - 0s 335us/step - loss: 0.0048 - mean_squared_error: 0.0011 - val_loss: 0.0146 - val_mean_squared_error: 0.0110
# Epoch 486/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0067 - mean_squared_error: 0.0031 - val_loss: 0.0150 - val_mean_squared_error: 0.0114
# Epoch 487/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0056 - mean_squared_error: 0.0019 - val_loss: 0.0149 - val_mean_squared_error: 0.0113
# Epoch 488/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0041 - mean_squared_error: 5.0595e-04 - val_loss: 0.0147 - val_mean_squared_error: 0.0110
# Epoch 489/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0045 - mean_squared_error: 9.2102e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0108
# Epoch 490/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0062 - mean_squared_error: 0.0026 - val_loss: 0.0134 - val_mean_squared_error: 0.0098
# Epoch 491/500
# 6/6 [==============================] - 0s 333us/step - loss: 0.0076 - mean_squared_error: 0.0039 - val_loss: 0.0125 - val_mean_squared_error: 0.0089
# Epoch 492/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0135 - mean_squared_error: 0.0099 - val_loss: 0.0105 - val_mean_squared_error: 0.0068
# Epoch 493/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0052 - mean_squared_error: 0.0016 - val_loss: 0.0088 - val_mean_squared_error: 0.0052
# Epoch 494/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0097 - mean_squared_error: 0.0061 - val_loss: 0.0078 - val_mean_squared_error: 0.0042
# Epoch 495/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0063 - mean_squared_error: 0.0027 - val_loss: 0.0069 - val_mean_squared_error: 0.0033
# Epoch 496/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0099 - mean_squared_error: 0.0063 - val_loss: 0.0066 - val_mean_squared_error: 0.0030
# Epoch 497/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0045 - mean_squared_error: 8.8670e-04 - val_loss: 0.0062 - val_mean_squared_error: 0.0026
# Epoch 498/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0080 - mean_squared_error: 0.0044 - val_loss: 0.0062 - val_mean_squared_error: 0.0026
# Epoch 499/500
# 6/6 [==============================] - 0s 499us/step - loss: 0.0055 - mean_squared_error: 0.0019 - val_loss: 0.0065 - val_mean_squared_error: 0.0029
# Epoch 500/500
# 6/6 [==============================] - 0s 332us/step - loss: 0.0070 - mean_squared_error: 0.0034 - val_loss: 0.0070 - val_mean_squared_error: 0.0034
# 4/4 [==============================] - 0s 249us/step
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.59s/it]

# %% [markdown]
# #### Display the results for ANN

# %%
Results_ANN = pd.DataFrame(Results_ANN_list, columns=['Number of nodes', 'Number of layers', 'Dropout rate',
                                                      'Number of epochs', 'Regularization penalty', 'R2_ANN',
                                                      'MSE_ANN'])
Results_ANN.sort_values(['R2_ANN'], ascending = False)
# Out:
#    Number of nodes  Number of layers  Dropout rate  Number of epochs  \
# 0              100                 2           0.1               500
#
#    Regularization penalty    R2_ANN   MSE_ANN
# 0                  0.0001  0.389307  0.037593

# %% [markdown]
# ## Regression

# %%
# Evaluate performance of regression models over different degrees

degree_range_regression = 5

Results_regression = []

plt.figure(figsize=(12, 10))
for deg in range(2, degree_range_regression):
    R2_regression, MSE_regression = Regression(X, y, sensor_name, score_name, deg,
                                               'plot')
    Results_regression.append([deg, R2_regression, MSE_regression])
# Out:
#    deg  R2_regression  MSE_regression
# 1    3       0.788090        0.101203
# 0    2       0.787782        0.101276
# 2    4      -2.184333        0.392307

# %% [markdown]
# #### Display the results for Regression

# %%
Results_regression = pd.DataFrame(Results_regression, columns=['deg', 'R2_regression', 'MSE_regression'])

Results_regression.sort_values(['R2_regression'], ascending = False)

# %% [markdown]
# ## Spline Regression

# %%
degree_range_spline = 5
quantiles_in_spline_regression = (0.25, 0.5, 0.75)

Results_splines = []

plt.figure(figsize=(12, 10))
for deg in range(2, degree_range_spline):
    R2_spline, MSE_spline = Spline_Regression(X, y, sensor_name, score_name, deg,
                                              quantiles_in_spline_regression, 'plot')
    Results_splines.append([deg, R2_spline, MSE_spline])
# Out:
#    deg  R2_spline  MSE_spline
# 0    2  -1.935745    0.376683
# 1    3  -2.794986    0.428274
# 2    4  -3.526591    0.467738

# %% [markdown]
# #### Display the results for Splines

# %%
Results_splines = pd.DataFrame(Results_splines, columns=['deg', 'R2_spline', 'MSE_spline'])

Results_splines.sort_values(['R2_spline'], ascending = False)
